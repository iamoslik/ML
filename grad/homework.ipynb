# %% [markdown]
# # Курс по машинному обучению,   ВМК МГУ
# ## Градиентный бустинг деревьев

# %% [markdown]
# ### Важно! О формате сдачи
#
# * **Практически все выделенные задания из ноутбука оцениваются по системе <font color='red'>кросс-рецензирования</font>. Задания, в котором надо реализовать свой код и послать в систему, выделены здесь и в pdf отдельно**
# * **В этом ноутбуке есть задание на ML-решение**
# * **При решении ноутбука используйте данный шаблон. Не нужно удалять текстовые ячейки c разметкой частей ноутбука и формулировками заданий. Добавлять свои ячейки, при необходимости, конечно можно**
# * **Везде, где в формулровке задания есть какой-либо вопрос (или просьба вывода), необходимо прописать ответ в ячейку (код или markdown).**
# * **Наличие кода решения обязательно. Письменные ответы на вопросы без сопутствующего кода оцениваются в 0 баллов.**

# %% [markdown]
# **А также..**
#
# Если в ячейке написана фраза "Вывод"/"Ответ на вопрос" итд, то ожидается ответ в виде текста (можете добавить ячейки с кодом, если считаете это необходимым, но это необязательно). Если в ячейке написано "Your code here", то ожидается ответ в виде кода (можете добавить ячейки с кодом, если считаете это необходимым, но это необязательно). Если есть и ячейка с фразой "Вывод", и ячейка с фразой "Your code here", то в ответе ожидается и код, и текст)

# %% [markdown]
# __В этом задании вы..:__
#
# - Познакомитесь с несколькими новыми библиотеками машинного обучения
# - Сравните между собой разные реализации градиентных бустингов
# - Примените все полученные знания для получения лучшего скора на датасете фильмов

# %% [markdown]
# ## Введение
#
# Привет, ребятушки!
#
# Сегодня мы с вами будем решать очень важную задачу, а именно оценивать цену поддержанных автомобилей в ряде стран. Делать мы это будем с помощью различных методов градиентного бустинга. Мы с вами узнаем, что в мире существует не только sklearn, и что существуют библиотеки, облегчающие нам задачу поиска оптимальных параметров для моделей.
#
# **Внимание! Во всех заданиях в качестве целевой метрики используется MAE (средняя абсолютная ошибка).** Значение MAE вычисляется как
#
# $$
#   MAE = \sum_{i = 1}^N\dfrac{|a(x_i) - y_i|}{N},
# $$
#
# где $N$ - число объектов в тестовой выборке, $x_i$ - вектор признаков i-го объекта, $a(x_i)$ - предсказание на i-ом объекте, $y_i$ - значение целевого признака на i-м объекте.

# %% [markdown]
# ## Установка дополнительных библиотек.
#
# В этом задании нам понадобятся три бибиотеки, которыми вы ранее не пользовались в этом курсе, а именно:
#
# **XGBoost**: Документация [здесь](https://xgboost.readthedocs.io/en/stable/).<br />
# **LightGBM**: Документация [здесь](https://lightgbm.readthedocs.io/en/latest/index.html). Также дополнительно про установку [тут](https://pypi.org/project/lightgbm/).<br />
# **Catboost**: Документация [здесь](https://catboost.ai/en/docs/). Можно найти также некоторую информацию на русском [тут](https://habr.com/ru/company/otus/blog/527554/).<br />
# **HyperOpt**: Документация [здесь](http://hyperopt.github.io/hyperopt/). <br />
#
# Все библиотеки легко ставятся через pip (либо альтернативные установщики вроде conda).

# %% [markdown]
# ## Как правильно перебирать параметры
#
# В этом ноутбуке мы будем несколько раз заниматься поиском оптимальных параметров для градиентного бустинга, перебирая задания по заданной сетке. В этом задании от Вас не будет требоваться найти самые лучшие параметры, но всё равно важно правильно составлять сетку для перебора. Для этого нужно понимать суть параметров и их смысл.
#
#
#
# **learning_rate** -- темп обучения нашего метода. Для этого метода сетка перебора должна быть логарифмической, т.е. перебирать порядковые значения (к примеру, [1e-3, 1e-2, 1e-1, 1]). В большинстве случаев достаточно перебрать значения от 1e-5 до 1.<br />
# **max_depth** -- максимальная глубина деревьев в ансамбле. Вообще говоря, эта величина зависит от числа признаков, но обычно лучше растить небольшие деревья. К примеру, библиотека CatBoost, которую мы будем исследовать сегодня, рекомендует перебирать значения до 10 (и уточняется, что обычно оптимальная глубина лежит от 6 до 10).<br />
# **n_estimators** -- количество деревьев в ансамбле. Обычно стоит перебирать с каким-то крупным шагом (можно по логарифмической сетке). Здесь важно найти баланс между производительностью, временем обучения и качеством. Обычно нескольких тысяч деревьев бывает достаточно.<br />
#
# Учтите, что в реальных задачах необходимо следить за тем, что оптимальные значения параметров не попадают на границы интервалов, т.е. что вы нашли хотя бы локальный минимум. Если Вы перебрали значения параметра от 1 до 10 и оказалось, что 10 - оптимальное значение, значит следует перебрать и бОльшие числа, чтобы убедиться, что качество не улучшается дальше (или по крайней мере убедиться, что рост качества сильно замедляется и на сильное улучшения рассчитывать не стоит.

# %% [markdown]
# ## Подготовка датасета
#
# Все библиотеки, используемые сегодня, мы будем проверять на одних и тех же параметрах: n_estimators=1000, max_depth=5, learning_rate=0.1. Таким образом мы устанавливаем, соответственно, число деревьев в ансамбле равным 1000, ограничиваем максимальную глубину деревьев 5 и устанавливаем темп обучения равным 0.1. Создадим сразу словарь, чтобы передавать эти параметры создаваемым регрессорам (если вдруг не знали, словарь можно передавать как параметры, поставив перед ним **).
#
# Эти параметры мы вынесем в отдельную переменную `test_parameters`.
#
# <span style="color:red">Загрузите датасет, с которым мы будем работать. Его можно найти на платформе cv-gml.ru, в задании `Град. бустинг (ML)`, по ссылке `Дополнительные файлы для решения`. Если Вы решите сохранить этот файл не рядом с ноутбуком, Вы можете исправить путь к этому файлу во второй ячейке ноутбука (в строке с `read_csv`).</span>
#
# При желании можно почитать про этот датасет на платформе kaggle: [ссылка на данные](https://www.kaggle.com/bushnag/cars-in-the-middle-east?select=dataframe_YesIndex_YesHeader_C.csv). <span style="color:red"> Не скачивайте датасет из kaggle для выполнения ноутбука, поскольку его могут изменить.</span> Нас интересует файл dataframe_YesIndex_YesHeader_C.csv, поскольку он уже хорошо предобработан (хотя, конечно, датасаентисты должны сами уметь это делать, но ладно).
# Давайте попробуем загрузить датасет в память и посмотреть, как он выглядит.

# %%
# %matplotlib inline
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.metrics import mean_absolute_error, make_scorer

from hyperopt import hp, tpe, Trials
from hyperopt.fmin import fmin
from hyperopt.pyll import scope

from xgboost import XGBRegressor

from lightgbm import LGBMRegressor

from catboost import CatBoostRegressor

import matplotlib.pyplot as plt

import pandas as pd

import numpy as np

import time
# Out:
# C:\Users\Olya\miniconda3\envs\prak\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\Olya\miniconda3\envs\prak\lib\site-packages\numpy\.libs\libopenblas.GK7GX5KEQ4F6UYO3P26ULGBQYHGQO7J4.gfortran-win_amd64.dll
# C:\Users\Olya\miniconda3\envs\prak\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
test_parameters = {"n_estimators": 1000, "max_depth": 5, "learning_rate":0.1}

df = pd.read_csv('dataframe_YesIndex_YesHeader_C.csv', index_col=0)
df.head()
# Out:
#    Engine Capacity  Cylinders  Drive Type  Fuel Tank Capacity  Fuel Economy  \
# 0              1.2          3           0                42.0           4.9
# 1              1.2          3           0                42.0           4.9
# 2              1.4          4           0                45.0           6.3
# 3              1.6          4           0                50.0           6.4
# 4              1.5          4           0                48.0           5.8
#
#    Fuel Type  Horsepower  Torque  Transmission  Top Speed  ...  Acceleration  \
# 0          0          76   100.0             0        170  ...          14.0
# 1          0          76   100.0             0        170  ...          14.0
# 2          0          75   118.0             1        156  ...          16.0
# 3          0         102   145.0             0        180  ...          11.0
# 4          0         112   150.0             0        170  ...          10.9
#
#    Length  Width  Height  Wheelbase  Trunk Capacity  \
# 0   4.245  1.670   1.515      2.550           450.0
# 1   4.245  1.670   1.515      2.550           450.0
# 2   3.864  1.716   1.721      2.513          2800.0
# 3   4.354  1.994   1.529      2.635           510.0
# 4   4.314  1.809   1.624      2.585           448.0
#
#                                      name    price  currency  Country
# 0  Mitsubishi Attrage 2021 1.2 GLX (Base)  34099.0         0        0
# 1  Mitsubishi Attrage 2021 1.2 GLX (Base)  34099.0         0        0
# 2         Fiat Fiorino 2021 1.4L Standard  41250.0         0        0
# 3             Renault Symbol 2021 1.6L PE  44930.0         0        0
# 4                     MG ZS 2021 1.5L STD  57787.0         0        0
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Задание 0 (без проверки, 0 баллов)
#
# Посмотрите на цены автомобилей. Попробуйте понять, написаны они в одной валюте или нет. Если нет -- будут ли у нас серьезные проблемы при использовании деревьев? Стоит ли нам что-то сделать для того, чтобы нивелировать эту проблему?

# %% [markdown]
# В глаза бросаются две проблемы: у нас имеется информация о производителе автомобиля, скрытая в текстовой переменной модели автомобиля (нет отдельного признака). Также имеются некоторые категориальные переменные. Со всем этим безобразием надо что-то сделать.
#
# ### **Задание 1 (кросс-проверка, 3 балла)**
# **Данные**: датасет со стоимостью поддержанных автомобилей
# **Цели**: В данном задании следует выполнить следующие пункты (выполнять можно в любом порядке)
# 1. Изучить датасет, проверить наличие пропусков. При необходимости заменить их на среднее значение признака.
# 3. Добавить столбец brand с информацией о производителе автомобиля (для простоты можно взять первое слово в названии модели)
# 4. Решить, какие признаки Вы хотите сделать категориальными. Конвертировать выбранные категориальные столбцы в тип category.
# 5. Создать датасет А с категориальными признаками в виде категорий. Для этого необходимо создать вектор целевых значений (столбец цен автомобилей) и матрицу признаков с категориальными переменными в виде категорий (получается путем удаления только целевой переменной из матрицы с данными). Дополнительно стоит создать список с названиями и индексами столбцов категориальных переменных (поможет в будущем).
# 6. Создать датасет B без категориальных признаков. Для этого необходимо создать вектор целевых значений (столбец цен автомобилей) и удалить из матрицы признаков столбец с целевыми переменными, а также все категориальные переменные.
# 8. Создать датасет C с категориальными признаками в виде one-hot encoding. Для этого необходимо создать вектор целевых значений (столбец цен автомобилей), удалить из матрицы признаков столбец с целевыми переменными и все категориальными переменные, а затем добавить новые признаки, соответствующие one-hot encoding категориальных переменных (здесь вам поможет функция `pd.get_dummies`).
# 9. Разбить датасеты на тренировочное и тестовое множества, используя `train_test_split(X, y, test_size=0.25, random_state=0)` (зафиксировав random_seed мы получим одинаковое разбиение на обучение/тест для всех трёх выборок).

# %%
datasets = {'A' : None, 'B': None, 'C': None}

# your awesome code here
#1
df_numeric = df.select_dtypes(include=[np.number])
numeric_cols = df_numeric.columns.values
count = 0
for col in numeric_cols:
    missing = df[col].isnull()
    num_missing = np.sum(missing)
    
    if num_missing > 0:  # only do the imputation for the columns that have missing values.
        print('imputing missing values for: {}'.format(col))
        df['{}_ismissing'.format(col)] = missing
        med = df[col].median()
        df[col] = df[col].fillna(med)
        count += 1
if count == 0:
    print("Пропуски отсутствуют")
# Out:
# Пропуски отсутствуют

# %%
#2
df['brand'] = df['name'].str.split().str[0]

# %%
#3
cols_to_exclude = ['Cylinders', 'Drive Type', 'Fuel Type', 'Transmission', 'currency', 'brand']
for col in cols_to_exclude:
    df[col] = df[col].astype('category')

df.drop('name', axis=1, inplace=True)

# %%
# 4
datasets['A'] = df

# %%
#5
datasets['B'] = df.drop(columns = ['price', 'Cylinders', 'Drive Type', 'Fuel Type', 'Transmission','currency', 'brand'], axis = 1)

# %%
#6
datasets['C'] = df[cols_to_exclude]
datasets['C'] = pd.get_dummies(datasets["C"])

# %%
#7
y = df['price'].to_numpy()
X_train = {'A' : None, 'B': None, 'C': None}
X_test = {'A' : None, 'B': None, 'C': None}
y_train = {'A' : None, 'B': None, 'C': None}
y_test = {'A' : None, 'B': None, 'C': None}

X_train['A'], X_test['A'], y_train['A'], y_test['A'] = train_test_split(datasets['A'], y, test_size=0.25, random_state=0)
X_train['B'], X_test['B'], y_train['B'], y_test['B'] = train_test_split(datasets['B'], y, test_size=0.25, random_state=0)
X_train['C'], X_test['C'], y_train['C'], y_test['C'] = train_test_split(datasets['C'], y, test_size=0.25, random_state=0)

# %%
df
# Out:
#       Engine Capacity Cylinders Drive Type  Fuel Tank Capacity  Fuel Economy  \
# 0                 1.2         3          0                42.0           4.9
# 1                 1.2         3          0                42.0           4.9
# 2                 1.4         4          0                45.0           6.3
# 3                 1.6         4          0                50.0           6.4
# 4                 1.5         4          0                48.0           5.8
# ...               ...       ...        ...                 ...           ...
# 5662              6.6        12          2                82.0          14.1
# 5663              6.8         8          2                96.0          15.0
# 5664              6.7        12          2               100.0          14.8
# 5665              6.5        12          1                90.0          16.0
# 5667              8.0        16          1               100.0          22.5
#
#      Fuel Type  Horsepower  Torque Transmission  Top Speed  ...  Acceleration  \
# 0            0          76   100.0            0        170  ...          14.0
# 1            0          76   100.0            0        170  ...          14.0
# 2            0          75   118.0            1        156  ...          16.0
# 3            0         102   145.0            0        180  ...          11.0
# 4            0         112   150.0            0        170  ...          10.9
# ...        ...         ...     ...          ...        ...  ...           ...
# 5662         0         563   820.0            0        250  ...           5.0
# 5663         0         530  1100.0            0        305  ...           4.9
# 5664         0         563   900.0            0        250  ...           5.3
# 5665         0         770   720.0            0        350  ...           2.8
# 5667         0        1500  1600.0            0        420  ...           2.4
#
#       Length  Width  Height  Wheelbase  Trunk Capacity      price  currency  \
# 0      4.245  1.670   1.515      2.550           450.0    34099.0         0
# 1      4.245  1.670   1.515      2.550           450.0    34099.0         0
# 2      3.864  1.716   1.721      2.513          2800.0    41250.0         0
# 3      4.354  1.994   1.529      2.635           510.0    44930.0         0
# 4      4.314  1.809   1.624      2.585           448.0    57787.0         0
# ...      ...    ...     ...        ...             ...        ...       ...
# 5662   5.285  1.947   1.502      3.112           283.0  1300000.0         2
# 5663   5.575  1.926   1.521      3.266           443.0  1600000.0         2
# 5664   5.762  2.018   1.646      3.552           548.0  1950000.0         2
# 5665   4.343  2.098   1.136      2.700           140.0  1850000.0         2
# 5667   4.544  2.037   1.212      2.711            45.0  9600000.0         2
#
#      Country        brand
# 0          0   Mitsubishi
# 1          0   Mitsubishi
# 2          0         Fiat
# 3          0      Renault
# 4          0           MG
# ...      ...          ...
# 5662       2        Rolls
# 5663       2      Bentley
# 5664       2        Rolls
# 5665       2  Lamborghini
# 5667       2      Bugatti
#
# [4560 rows x 21 columns]

# %% [markdown]
# Итак, кажется, что у нас всё готово для того, чтобы начать искать ответы на волнующие нас вопросы. Начнем со столь любимой нами библиотеки, а именно...
#
# ## Градиентный бустинг со sklearn
#
# Естественно, в sklearn имеется реализация градиентного бустинга, которая хранится в sklearn.ensemble.GradientBoostingRegressor. Преимущественно данным классом пользуются в учебных заданиях, поскольку в реальных задачах предпочтение отдаётся другим библиотекам. Давайте попробуем понять, заслуженно ли градиентный бустинг в sklearn не пользуется популярностью.
#
# FYI: в sklearn имеется также реализация GradientBoostingClassifier для задач классификации, но пользоваться им мы сегодня не будем.
#
# GradientBoostingRegressor из коробки не умеет работать с категориальными признаками. Мы к этому уже подготовились, закодировав наши признаки.
#
# ### **Задание 2 (кросс-проверка, 2 балла)**:
#
# **Данные**: датасет со стоимостью поддержанных автомобилей
# **Метрика**: MAE
# **Цели**: В данном задании следует выполнить следующие пункты:
# 1. Обучить sklearn.ensemble.GradientBoostingRegressor на датасетах B и C, используя параметры n_estimators=1000, max_depth=5, learning_rate=0.1 (наши `test_parameters`). Замерьте время обучения, получите предсказания данных моделей на тестовом множестве.
# 2. Обучить sklearn.ensemble.GradientBoostingRegressor на датасете B (можно и на C, если позволяют вычислительные ресурсы), используя кросс-валидацию на тренировочном множестве и подбирая значения для параметров n_estimators, learning_rate и max_depth. для простоты можете воспользоваться GridSearchCV. При необходимости можно оптимизировать параметры по одному, а не все сразу. Выведите лучшие параметры. Получите предсказания лучшей модели (с лучшими параметрами) на тестовом множестве. Для ускорения процесса не забудьте воспользоваться n_jobs.
# 3. Посчитать MAE для полученных предсказаний на тренировочном и тестовом множествах (можно воспользоваться sklearn.metrics.mean_absolute_error).
# 5. Вывести результаты и время в таблице DataFrame.
# 4. Сделайте выводы. Оцените полезность категориальных переменных и поиска оптимальных параметров. Оцените время, затраченное на обучение. Попробуйте дать оценку получившемуся MAE: оно большое или маленькое?

# %%
df_skl = pd.DataFrame(columns=['Dataset', 'Parameters', 'Time', 'MAE'])

# your cool code here
def insert(df, row):
    insert_loc = df.index.max()

    if pd.isna(insert_loc):
        df.loc[0] = row
    else:
        df.loc[insert_loc + 1] = row

# %%
#1
for i in ['B', 'C']:
    gbr = GradientBoostingRegressor(n_estimators = 1000, max_depth = 5, learning_rate = 0.1)
    t = time.time()
    gbr.fit(X_train[i], y_train[i])
    mae = mean_absolute_error(y_test[i], gbr.predict(X_test[i]))
    insert(df_skl, [i+'_test', {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 1000}, time.time() - t, mae])

# %%
#2
gbr = GradientBoostingRegressor()
param_grid = {
        "n_estimators": [100, 1000, 2000],
        "learning_rate": [1e-2, 1e-1, 1],
        "max_depth"   : [5, 6, 7],
}
# Perform grid search, fit it, and print score
t = time.time()
regressor = GridSearchCV(estimator = gbr, param_grid = param_grid, cv = 2, n_jobs = -1)
regressor.fit(X_train['B'], y_train['B'])
time = time.time() - t
predictions_test = regressor.predict(X_test['B'])
predictions_train = regressor.predict(X_train['B'])
print("BEST PARAMETERS:", regressor.best_params_)
print("BEST SCORE:", regressor.best_score_)
# Out:
# BEST PARAMETERS: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 2000}
# BEST SCORE: 0.8641427581784978

# %%
# 3
mae_train = mean_absolute_error(predictions_train, y_train['B'])
mae_test  = mean_absolute_error(predictions_test, y_test['B'])
insert(df_skl, ['B train', regressor.best_params_, time, mae_train])
insert(df_skl, ['B test', regressor.best_params_, time, mae_test])
print("MAE (train):", mae_train)
print("MAE (test) :", mae_test)
# Out:
# MAE (train): 9309.891242388108
# MAE (test) : 15784.1807994214

# %%
df_skl
# Out:
#    Dataset                                         Parameters       Time  \
# 0   B_test  {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...   6.845714
# 1   C_test  {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...   6.111360
# 2  B train  {'learning_rate': 0.01, 'max_depth': 5, 'n_est...  91.696990
# 3   B test  {'learning_rate': 0.01, 'max_depth': 5, 'n_est...  91.696990
#
#             MAE
# 0  14499.848994
# 1  26048.684892
# 2   9309.891242
# 3  15784.180799

# %% [markdown]
# **Ваши выводы:** Категориальные признаки полезны. Поиск оптимальных параметров немного улучшил качество. Время, затраченное на обучение достаточно большое. MAE большое.

# %% [markdown]
# И так, sklearn предлагает нам привычный и простой способ тренировки моделей. Однако, для градиентного бустинга существует множество эвристик и трюков, помогающих улучшить результаты. И одна из библиотек, реализующая улучшенную версию бустинга, называется xgboost.
#
# ## Градиентный бустинг с XGBoost
#
# XGBoost стала достаточно популярной библиотекой, которая позволяет добиться хороших результатов без особых усилий (во всяком случае, так гласят легенды). И у нас для вас две новости: хорошая и плохая. Хорошая – xgboost, хоть и является сторонней библиотекой, сохраняет интерфейс sklearn и даже прекрасно работает с GridSearchCV. Плохая – она тоже не умеет из коробки работать с категориальными признаками. Ну что же, давайте пощупаем это безобразие. На этот раз нас интересует класс xgboost.XGBRegressor.
#
# Update: относительно недавно в xgboost появилась экспериментальная поддержка категориальных переменных, которая еще не добавлена в стабильную версию, поэтому ею мы пользоваться пока не будем.
#
# ### Задание 3 (кросс-проверка, 2 балла):
# **Данные**: датасет со стоимостью поддержанных автомобилей
# **Метрика**: MAE
# **Цели**: В данном задании следует выполнить следующие пункты:
# 1. Обучить xgboost.XGBRegressor на датасетах B и C, используя параметры n_estimators=1000, max_depth=5, learning_rate=0.1 (наши `test_parameters`). Замерьте время обучения. Получите предсказания данных моделей на тестовом множестве.
# 2. Обучить xgboost.XGBRegressor на датасетах B и C, используя кросс-валидацию на тренировочном множестве и подбирая значения для параметров n_estimators, learning_rate и max_depth (для простоты можете воспользоваться GridSearchCV). При необходимости можно оптимизировать параметры по одному, а не все сразу. Замерьте время перебора, получите предсказания лучшей модели (с лучшими параметрами) на тестовом множестве. В этом случае устанавливать n_jobs у GridSearchCV не рекомендую, поскольку xgboost сам умеет захватывать все доступные ресурсы, и если GridSearchCV начнет их размножать, то последствия будут печальны.
# 3. Посчитать MAE для полученных предсказаний на тренировочном и тестовом множествах (можно воспользоваться sklearn.metrics.mean_absolute_error).
# 1. Выведите результаты и время в таблице DataFrame.
# 4. Сделайте выводы. Оцените полезность категориальных переменных и поиска оптимальных параметров. Оцените время, затраченное на обучение. Сравните результаты со sklearn.

# %%
df_xgbr = pd.DataFrame(columns=['Dataset', 'Parameters', 'Time', 'MAE'])

# your perfect code here
import time
# 1
for i in ['B', 'C']:
    xgbr = XGBRegressor(n_estimators=1000, max_depth=5, learning_rate=0.1)
    t = time.time()
    xgbr.fit(X_train[i], y_train[i])
    mae = mean_absolute_error(y_test[i], xgbr.predict(X_test[i]))
    insert(df_xgbr, [i+'_test', {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 1000}, time.time() - t, mae])

# %%
# 2, 3
param_grid = {
        "n_estimators": [100, 1000, 2000], 
        "max_depth"   : [5, 6, 7],
        "learning_rate": [1e-2, 1e-1, 1]
}
for i in ['B', 'C']:
    xgbr = XGBRegressor()
    t = time.time()
    regressor = GridSearchCV(estimator = xgbr, param_grid = param_grid, cv = 2)
    regressor.fit(X_train[i], y_train[i])
    res_t = time.time() - t
    predictions_test = regressor.predict(X_test[i])
    predictions_train = regressor.predict(X_train[i])
    mae_train = mean_absolute_error(predictions_train, y_train[i])
    mae_test  = mean_absolute_error(predictions_test, y_test[i])
    insert(df_xgbr, [i + '_train', regressor.best_params_, res_t, mae_train])
    insert(df_xgbr, [i + '_test', regressor.best_params_, res_t, mae_test])
    print("BEST PARAMETERS", i, ':', regressor.best_params_)
    print("BEST SCORE:", i, ':', regressor.best_score_)

df_xgbr
# Out:
# BEST PARAMETERS B : {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 2000}
# BEST SCORE: B : 0.6460260715596144
# BEST PARAMETERS C : {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 2000}
# BEST SCORE: C : 0.8434383169493019
#    Dataset                                         Parameters        Time  \
# 0   B_test  {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...    1.331653
# 1   C_test  {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...    2.567647
# 2  B_train  {'learning_rate': 0.01, 'max_depth': 5, 'n_est...   78.616176
# 3   B_test  {'learning_rate': 0.01, 'max_depth': 5, 'n_est...   78.616176
# 4  C_train  {'learning_rate': 0.01, 'max_depth': 7, 'n_est...  133.012072
# 5   C_test  {'learning_rate': 0.01, 'max_depth': 7, 'n_est...  133.012072
#
#             MAE
# 0  14546.763110
# 1  26825.668841
# 2  10348.414886
# 3  16612.634077
# 4  24293.619046
# 5  30169.897032

# %% [markdown]
# **Ваши выводы:**  Категориальные признаки достточно полезны, как и в предыдущем случае. MAE немного меньше, чем в ппредыдущем случае. но все еще большой. Время обучения на оптимальных параметрах сильно больше, чем на заданных.

# %% [markdown]
# Таким вот несложным образом нам удалось воспользоваться еще одной библиотекой. Давайте перейдем к третьей библиотеке, которую мы сегодня изучим, и называется она lightgbm.
#
# ## Градиентный бустинг в lightgbm
#
# Про Lightgbm легенды гласят, что она очень быстрая и легкая: что самый большой датасет она без проблем переварит за относительно небольшое время. А еще её разрабатывали не хухры кто, а сами мелкомягкие, так что попробовать её определённо стоит. На этот раз у нас вновь две новости, две хороших и две плохих. Первая хорошая — lightgbm тоже работает с GridSearchCV. Вторая хорошая — lightgbm умеет из коробки работать с категориальными признаками! Плохая — делает она это немного нетривиально (не зря я просил вас запомнить категориальные переменные!). Вторая плохая — да, нам придётся этим пользоваться.
#
# Внимание! LightGBM может писать сотню радостных сообщений о том, что он увидел ваши categorical_feature и использует их. При желании можете заглушать эти оповещения, ибо в случае перебора параметров их становится слишком много. (заклинание для заглушения: `warnings.filterwarnings("ignore")`)
#
# ### Задание 4 (кросс-проверка, 3 балла):
# **Данные**: датасет со стоимостью поддержанных автомобилей
# **Метрика**: MAE
# **Цели**: В данном задании следует выполнить следующие пункты:
# 1. В случае датасета, сохраненном в numpy, lightgbm требует, чтобы категории были закодированы целыми числами от 0 до числа признаков(e.g. ['a', 'b', 'a'] -> [0, 1, 0]). Сделайте это для датасета A. Если вы используете pandas, то для датасета A достаточно установить соответствующие столбцы типа "категория", тогда categorical_feature='auto' сам всё подхватит.
# 2. Обучить lightgbm.LGBMRegressor на датасетах A, B и C, используя параметры используя параметры n_estimators=1000, max_depth=5, learning_rate=0.1. В случае датасета A, передайте в функцию fit индексы/имена категориальных признаков. Замерьте время обучения, получите предсказания данных моделей на тестовом множестве.
# 3. Обучить lightgbm.LGBMRegressor на датасетах A, B и C, используя кросс-валидацию на тренировочном множестве и подбирая значения для параметров n_estimators, learning_rate и max_depth (для простоты можете воспользоваться GridSearchCV). Замерьте время, потраченное на поиск оптимальных параметров(вновь не советую использовать n_jobs). Замерьте время перебора, получите предсказания лучшей модели (с лучшими параметрами) на тестовом множестве.
# 4. Посчитать MAE для полученных предсказаний на тренировочном и тестовом множествах (можно воспользоваться sklearn.metrics.mean_absolute_error). Сделайте выводы и полезности использования категориальных переменных и поиска оптимальных параметров.
# 5. Вывести результаты и время в таблице DataFrame.

# %%
import warnings
warnings.filterwarnings("ignore")

df_lightgbm = pd.DataFrame(columns=['Dataset', 'Parameters', 'Time', 'MAE'])

# your great code here
param_grid = {
        "n_estimators": [100, 1000, 2000], 
        "max_depth"   : [5, 6, 7],
        "learning_rate": [1e-2, 1e-1, 1]
}

# %%
#1
for i in ['A', 'B', 'C']:
    if i == 'A':
        model = LGBMRegressor(categorical_feature = 'auto', n_estimators = 1000, max_depth = 5, learning_rate = 0.1)
    else:
        model = LGBMRegressor(n_estimators = 1000, max_depth = 5, learning_rate = 0.1)
    t = time.time()
    model.fit(X_train[i], y_train[i])
    mae = mean_absolute_error(y_test[i], model.predict(X_test[i]))
    insert(df_lightgbm, [i+'_test', {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 1000}, time.time() - t, mae])

# %%
#2
for i in ['A', 'B', 'C']:
    if i == 'A':
        model = LGBMRegressor(categorical_feature='auto')
    else:
        model = LGBMRegressor()
    # Perform grid search, fit it, and print score
    t = time.time()
    regressor = GridSearchCV(estimator = model, param_grid = param_grid, cv=2)
    regressor.fit(X_train[i], y_train[i])
    res_t = time.time() - t
    predictions_test = regressor.predict(X_test[i])
    predictions_train = regressor.predict(X_train[i])
    mae_train = mean_absolute_error(predictions_train, y_train[i])
    mae_test  = mean_absolute_error(predictions_test, y_test[i])
    insert(df_lightgbm, [i + '_train', regressor.best_params_, res_t, mae_train])
    insert(df_lightgbm, [i + '_test', regressor.best_params_, res_t, mae_test])
    print("BEST_PARAMETERS", i, ':', regressor.best_params_)
    print("BEST SCORE:", i, ':', regressor.best_score_)
# Out:
# BEST_PARAMETERS A : {'learning_rate': 1, 'max_depth': 5, 'n_estimators': 1000}
# BEST SCORE: A : 0.9726866883811597
# BEST_PARAMETERS B : {'learning_rate': 1, 'max_depth': 7, 'n_estimators': 100}
# BEST SCORE: B : 0.7973401098446922
# BEST_PARAMETERS C : {'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 2000}
# BEST SCORE: C : 0.40749477607196904

# %%
df_lightgbm
# Out:
#    Dataset                                         Parameters       Time  \
# 0   A_test  {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...   0.320870
# 1   B_test  {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...   0.265937
# 2   C_test  {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...   0.358129
# 3  A_train  {'learning_rate': 1, 'max_depth': 5, 'n_estima...  28.016402
# 4   A_test  {'learning_rate': 1, 'max_depth': 5, 'n_estima...  28.016402
# 5  B_train  {'learning_rate': 1, 'max_depth': 7, 'n_estima...  21.961574
# 6   B_test  {'learning_rate': 1, 'max_depth': 7, 'n_estima...  21.961574
# 7  C_train  {'learning_rate': 0.01, 'max_depth': 6, 'n_est...  21.827969
# 8   C_test  {'learning_rate': 0.01, 'max_depth': 6, 'n_est...  21.827969
#
#             MAE
# 0   4597.934259
# 1  25058.799643
# 2  49107.071433
# 3    190.021027
# 4   6266.294006
# 5  18593.188201
# 6  33761.885634
# 7  57269.463616
# 8  51462.120560

# %% [markdown]
# Как вы видите, иногда можно не возиться с OHE, а позволить библиотекам самим это сделать (хотя иногда при этом приходится повозиться с самими данными, чтобы библиотека съела данные).
#
# Итак, мы с вами почти стали мастерами градиентного бустинга. Переходим к последней звезде нашего хит-парада.

# %% [markdown]
# ## Градиентный бустинг в catboost
#
# Библиотека, созданная в тёмных подвалах яндекса. По легендам эта библиотека умеет работать с категориальными данными, быстрая, эффективная, легко настраивается, из коробки понимает текстовые признаки в задачах классификации и спасла Брюса Уиллиса. Давайте проверим.
# Вас, наверное, не удивить тем, что эта библиотека работает с GridSearchCV, но им мы пользоваться не будем. В catboost существует своя реализация перебора параметров, и мы попробуем им воспользоваться (ура, разнообразие!). В качестве регрессора нас интересует catboost.CatBoostRegressor.
#
# Внимание! Эта библиотека еще более болтлива, чем lightgbm, но это (почти) полностью лечится с помощью verbose. К сожалению, отключением warnings её не сделать молчаливее. А еще эта библиотека может неожиданно создать вам парочку новых папок.
#
# ### Задание 5 (кросс-проверка, 3 балла):
# **Данные**: датасет со стоимостью поддержанных автомобилей
# **Метрика**: MAE
# **Цели**: В данном задании следует выполнить следующие пункты:
# 1. Обучить catboost.CatBoostRegressor на датасетах A, B и C, используя параметры используя параметры n_estimators=1000, max_depth=5, learning_rate=0.1. В случае датасета A, передайте на вход методу fit/конструктору параметр cat_features, содержащий имена/индексы категориальных переменных. В данном случае переводить категории в целые числа, как мы делали для lightgbm, не нужно. Замерьте время обучения, получите предсказания данных моделей на тестовом множестве.
# 2. Обучить catboost.CatBoostRegressor на датасетах A, B и C, используя метод grid_search (является методом экземпляра класса CatBoostRegressor). Замерьте время, потраченное на поиск оптимальных параметров. Замерьте время перебора, получите предсказания лучшей модели (с лучшими параметрами) на тестовом множестве.
# 3. Посчитать MAE для полученных предсказаний на тренировочном и тестовом множествах (можно воспользоваться sklearn.metrics.mean_absolute_error).
# 4. Сделайте выводы и полезности использования категориальных переменных и поиска оптимальных параметров.
# 5. Вывести результаты и время в таблице DataFrame.

# %%
df_catboost = pd.DataFrame(columns=['Dataset', 'Parameters', 'Time', 'MAE'])

# your ideal code here
#1
for i in ['A', 'B', 'C']:
    if i == 'A':
        model = CatBoostRegressor(cat_features = cols_to_exclude, n_estimators = 1000, max_depth = 5, learning_rate = 0.1)
    else:
        model = CatBoostRegressor(n_estimators = 1000, max_depth = 5, learning_rate = 0.1)
    t = time.time()
    model.fit(X_train[i], y_train[i])
    mae = mean_absolute_error(y_test[i], model.predict(X_test[i]))
    insert(df_catboost, [i+'_test', {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 1000}, time.time() - t, mae])
# Out:
# 0:	learn: 355654.4950868	total: 171ms	remaining: 2m 50s
# 1:	learn: 334301.0393358	total: 206ms	remaining: 1m 43s
# 2:	learn: 314942.5168257	total: 234ms	remaining: 1m 17s
# 3:	learn: 295918.2600520	total: 257ms	remaining: 1m 4s
# 4:	learn: 278101.3047888	total: 277ms	remaining: 55s
# 5:	learn: 262246.7398678	total: 294ms	remaining: 48.7s
# 6:	learn: 247694.6182734	total: 309ms	remaining: 43.8s
# 7:	learn: 234028.0088193	total: 323ms	remaining: 40s
# 8:	learn: 221104.8353526	total: 336ms	remaining: 37s
# 9:	learn: 209724.5923713	total: 351ms	remaining: 34.8s
# 10:	learn: 197996.1571174	total: 369ms	remaining: 33.2s
# 11:	learn: 187550.2767666	total: 384ms	remaining: 31.7s
# 12:	learn: 179245.0891716	total: 395ms	remaining: 30s
# 13:	learn: 169233.2503664	total: 408ms	remaining: 28.8s
# 14:	learn: 160537.6572362	total: 423ms	remaining: 27.8s
# 15:	learn: 152127.0217107	total: 437ms	remaining: 26.9s
# 16:	learn: 144591.4328918	total: 452ms	remaining: 26.2s
# 17:	learn: 136918.7539196	total: 467ms	remaining: 25.5s
# 18:	learn: 129891.4545858	total: 481ms	remaining: 24.9s
# 19:	learn: 124444.1900781	total: 495ms	remaining: 24.3s
# 20:	learn: 118467.1129536	total: 509ms	remaining: 23.7s
# 21:	learn: 113377.2449403	total: 520ms	remaining: 23.1s
# 22:	learn: 107670.2653624	total: 534ms	remaining: 22.7s
# 23:	learn: 102337.2768001	total: 548ms	remaining: 22.3s
# 24:	learn: 98284.7973159	total: 557ms	remaining: 21.7s
# 25:	learn: 93579.9490357	total: 574ms	remaining: 21.5s
# 26:	learn: 89034.8673400	total: 593ms	remaining: 21.4s
# 27:	learn: 84538.1131698	total: 608ms	remaining: 21.1s
# 28:	learn: 80743.7431862	total: 622ms	remaining: 20.8s
# 29:	learn: 77036.8216670	total: 637ms	remaining: 20.6s
# 30:	learn: 73688.5038423	total: 651ms	remaining: 20.4s
# 31:	learn: 70411.1425010	total: 666ms	remaining: 20.1s
# 32:	learn: 67239.2314327	total: 680ms	remaining: 19.9s
# 33:	learn: 64802.6321603	total: 694ms	remaining: 19.7s
# 34:	learn: 61784.6414317	total: 708ms	remaining: 19.5s
# 35:	learn: 59244.6198577	total: 722ms	remaining: 19.3s
# 36:	learn: 57911.2679831	total: 737ms	remaining: 19.2s
# 37:	learn: 55750.2389307	total: 751ms	remaining: 19s
# 38:	learn: 54131.5383854	total: 768ms	remaining: 18.9s
# 39:	learn: 52377.0423626	total: 785ms	remaining: 18.8s
# 40:	learn: 51280.3183466	total: 799ms	remaining: 18.7s
# 41:	learn: 49973.9769142	total: 813ms	remaining: 18.6s
# 42:	learn: 48317.6114355	total: 827ms	remaining: 18.4s
# 43:	learn: 46843.3827975	total: 841ms	remaining: 18.3s
# 44:	learn: 45946.0946199	total: 855ms	remaining: 18.1s
# 45:	learn: 45101.6389639	total: 866ms	remaining: 17.9s
# 46:	learn: 44210.5909887	total: 875ms	remaining: 17.7s
# 47:	learn: 43459.3248964	total: 887ms	remaining: 17.6s
# 48:	learn: 42053.2958874	total: 901ms	remaining: 17.5s
# 49:	learn: 41501.5832955	total: 915ms	remaining: 17.4s
# 50:	learn: 40859.2470727	total: 928ms	remaining: 17.3s
# 51:	learn: 39785.4785864	total: 943ms	remaining: 17.2s
# 52:	learn: 38838.6103575	total: 957ms	remaining: 17.1s
# 53:	learn: 37975.4514227	total: 977ms	remaining: 17.1s
# 54:	learn: 37240.2634654	total: 994ms	remaining: 17.1s
# 55:	learn: 36499.6645896	total: 1.01s	remaining: 17s
# 56:	learn: 36045.1256186	total: 1.02s	remaining: 16.9s
# 57:	learn: 35644.0944469	total: 1.04s	remaining: 16.9s
# 58:	learn: 34847.3075135	total: 1.08s	remaining: 17.2s
# 59:	learn: 34426.0142664	total: 1.1s	remaining: 17.2s
# 60:	learn: 34081.8892267	total: 1.11s	remaining: 17.1s
# 61:	learn: 33659.4936118	total: 1.13s	remaining: 17.1s
# 62:	learn: 32885.9293242	total: 1.14s	remaining: 17s
# 63:	learn: 32500.5854617	total: 1.16s	remaining: 16.9s
# 64:	learn: 31905.7037084	total: 1.17s	remaining: 16.9s
# 65:	learn: 31595.6170214	total: 1.19s	remaining: 16.8s
# 66:	learn: 31349.2947768	total: 1.2s	remaining: 16.8s
# 67:	learn: 31096.1552032	total: 1.22s	remaining: 16.7s
# 68:	learn: 30872.4839486	total: 1.23s	remaining: 16.6s
# 69:	learn: 30663.1609493	total: 1.24s	remaining: 16.5s
# 70:	learn: 30020.6896326	total: 1.26s	remaining: 16.5s
# 71:	learn: 29245.8495496	total: 1.27s	remaining: 16.4s
# 72:	learn: 28988.0562566	total: 1.29s	remaining: 16.4s
# 73:	learn: 28711.8858624	total: 1.3s	remaining: 16.3s
# 74:	learn: 28467.3053129	total: 1.34s	remaining: 16.5s
# 75:	learn: 28306.8660799	total: 1.36s	remaining: 16.5s
# 76:	learn: 28076.0070330	total: 1.37s	remaining: 16.5s
# 77:	learn: 27908.3417927	total: 1.39s	remaining: 16.4s
# 78:	learn: 27705.3769448	total: 1.4s	remaining: 16.4s
# 79:	learn: 27544.9087683	total: 1.42s	remaining: 16.3s
# 80:	learn: 26951.5582875	total: 1.43s	remaining: 16.3s
# 81:	learn: 26477.3642513	total: 1.45s	remaining: 16.2s
# 82:	learn: 25840.7599292	total: 1.46s	remaining: 16.2s
# 83:	learn: 25409.6103882	total: 1.48s	remaining: 16.1s
# 84:	learn: 25240.9352824	total: 1.49s	remaining: 16s
# 85:	learn: 25117.0731690	total: 1.5s	remaining: 16s
# 86:	learn: 24979.1123213	total: 1.52s	remaining: 15.9s
# 87:	learn: 24832.2772446	total: 1.53s	remaining: 15.9s
# 88:	learn: 24691.3224809	total: 1.55s	remaining: 15.8s
# 89:	learn: 24573.9441440	total: 1.56s	remaining: 15.8s
# 90:	learn: 24145.9979957	total: 1.58s	remaining: 15.8s
# 91:	learn: 23771.4345234	total: 1.59s	remaining: 15.7s
# 92:	learn: 23659.4360531	total: 1.61s	remaining: 15.7s
# 93:	learn: 23541.9392990	total: 1.63s	remaining: 15.7s
# 94:	learn: 23080.9999968	total: 1.64s	remaining: 15.6s
# 95:	learn: 22632.8577743	total: 1.67s	remaining: 15.7s
# 96:	learn: 22423.4957955	total: 1.69s	remaining: 15.7s
# 97:	learn: 22359.9675223	total: 1.7s	remaining: 15.7s
# 98:	learn: 22127.8875403	total: 1.72s	remaining: 15.6s
# 99:	learn: 22044.3057255	total: 1.73s	remaining: 15.6s
# 100:	learn: 21786.8594815	total: 1.75s	remaining: 15.5s
# 101:	learn: 21725.8847828	total: 1.76s	remaining: 15.5s
# 102:	learn: 21696.2737933	total: 1.78s	remaining: 15.5s
# 103:	learn: 21313.2454631	total: 1.79s	remaining: 15.4s
# 104:	learn: 21196.6856845	total: 1.81s	remaining: 15.4s
# 105:	learn: 20971.4337219	total: 1.82s	remaining: 15.4s
# 106:	learn: 20751.8310362	total: 1.84s	remaining: 15.3s
# 107:	learn: 20493.8818930	total: 1.85s	remaining: 15.3s
# 108:	learn: 20160.7077905	total: 1.87s	remaining: 15.3s
# 109:	learn: 19847.6252030	total: 1.88s	remaining: 15.2s
# 110:	learn: 19707.7676525	total: 1.9s	remaining: 15.2s
# 111:	learn: 19509.8574137	total: 1.91s	remaining: 15.1s
# 112:	learn: 19350.8212724	total: 1.92s	remaining: 15.1s
# 113:	learn: 19081.9689719	total: 1.94s	remaining: 15.1s
# 114:	learn: 19045.1421362	total: 1.95s	remaining: 15s
# 115:	learn: 18838.1569955	total: 1.97s	remaining: 15s
# 116:	learn: 18806.1935000	total: 1.98s	remaining: 15s
# 117:	learn: 18543.7530517	total: 2.03s	remaining: 15.2s
# 118:	learn: 18312.3283891	total: 2.05s	remaining: 15.2s
# 119:	learn: 18252.6074166	total: 2.06s	remaining: 15.1s
# 120:	learn: 18223.8732342	total: 2.08s	remaining: 15.1s
# 121:	learn: 18021.4876215	total: 2.09s	remaining: 15.1s
# 122:	learn: 17950.1220615	total: 2.1s	remaining: 15s
# 123:	learn: 17893.2812454	total: 2.12s	remaining: 15s
# 124:	learn: 17807.4307762	total: 2.13s	remaining: 14.9s
# 125:	learn: 17637.0449034	total: 2.15s	remaining: 14.9s
# 126:	learn: 17510.0312159	total: 2.16s	remaining: 14.9s
# 127:	learn: 17455.4473746	total: 2.18s	remaining: 14.9s
# 128:	learn: 17311.6463257	total: 2.2s	remaining: 14.8s
# 129:	learn: 17224.2452865	total: 2.21s	remaining: 14.8s
# 130:	learn: 16978.5081176	total: 2.23s	remaining: 14.8s
# 131:	learn: 16846.9525289	total: 2.24s	remaining: 14.7s
# 132:	learn: 16675.5930566	total: 2.26s	remaining: 14.7s
# 133:	learn: 16510.7348647	total: 2.27s	remaining: 14.7s
# 134:	learn: 16490.2802479	total: 2.28s	remaining: 14.6s
# 135:	learn: 16385.2831326	total: 2.3s	remaining: 14.6s
# 136:	learn: 16200.2652098	total: 2.31s	remaining: 14.6s
# 137:	learn: 15996.9444947	total: 2.33s	remaining: 14.5s
# 138:	learn: 15928.5974384	total: 2.34s	remaining: 14.5s
# 139:	learn: 15779.2683660	total: 2.36s	remaining: 14.5s
# 140:	learn: 15627.9271227	total: 2.4s	remaining: 14.6s
# 141:	learn: 15535.3133425	total: 2.42s	remaining: 14.6s
# 142:	learn: 15452.0978063	total: 2.44s	remaining: 14.6s
# 143:	learn: 15376.5590215	total: 2.45s	remaining: 14.6s
# 144:	learn: 15359.3229658	total: 2.47s	remaining: 14.5s
# 145:	learn: 15231.3074996	total: 2.48s	remaining: 14.5s
# 146:	learn: 15074.0607793	total: 2.49s	remaining: 14.5s
# 147:	learn: 15013.8570871	total: 2.53s	remaining: 14.6s
# 148:	learn: 14977.8043229	total: 2.55s	remaining: 14.6s
# 149:	learn: 14843.3422756	total: 2.56s	remaining: 14.5s
# 150:	learn: 14813.4367423	total: 2.58s	remaining: 14.5s
# 151:	learn: 14762.4953715	total: 2.6s	remaining: 14.5s
# 152:	learn: 14683.5046474	total: 2.62s	remaining: 14.5s
# 153:	learn: 14524.8395647	total: 2.63s	remaining: 14.5s
# 154:	learn: 14413.7460417	total: 2.65s	remaining: 14.4s
# 155:	learn: 14255.2801116	total: 2.66s	remaining: 14.4s
# 156:	learn: 14180.0462327	total: 2.68s	remaining: 14.4s
# 157:	learn: 14066.7447551	total: 2.69s	remaining: 14.3s
# 158:	learn: 13995.3798441	total: 2.71s	remaining: 14.3s
# 159:	learn: 13956.6698623	total: 2.72s	remaining: 14.3s
# 160:	learn: 13829.4346218	total: 2.73s	remaining: 14.3s
# 161:	learn: 13746.3484500	total: 2.75s	remaining: 14.2s
# 162:	learn: 13644.0538080	total: 2.77s	remaining: 14.2s
# 163:	learn: 13592.4792454	total: 2.78s	remaining: 14.2s
# 164:	learn: 13509.6987694	total: 2.8s	remaining: 14.2s
# 165:	learn: 13411.5450930	total: 2.81s	remaining: 14.1s
# 166:	learn: 13395.3080724	total: 2.83s	remaining: 14.1s
# 167:	learn: 13299.4933024	total: 2.85s	remaining: 14.1s
# 168:	learn: 13197.7702301	total: 2.86s	remaining: 14.1s
# 169:	learn: 13182.6219087	total: 2.88s	remaining: 14s
# 170:	learn: 13105.1501733	total: 2.89s	remaining: 14s
# 171:	learn: 12988.5632022	total: 2.9s	remaining: 14s
# 172:	learn: 12890.2496421	total: 2.92s	remaining: 13.9s
# 173:	learn: 12835.8973322	total: 2.93s	remaining: 13.9s
# 174:	learn: 12749.9446663	total: 2.95s	remaining: 13.9s
# 175:	learn: 12682.6352268	total: 2.96s	remaining: 13.9s
# 176:	learn: 12587.4008706	total: 2.98s	remaining: 13.8s
# 177:	learn: 12544.2286973	total: 2.99s	remaining: 13.8s
# 178:	learn: 12525.1295350	total: 3.01s	remaining: 13.8s
# 179:	learn: 12447.9633478	total: 3.02s	remaining: 13.8s
# 180:	learn: 12386.8751560	total: 3.06s	remaining: 13.8s
# 181:	learn: 12378.1522469	total: 3.07s	remaining: 13.8s
# 182:	learn: 12295.9642401	total: 3.09s	remaining: 13.8s
# 183:	learn: 12215.1625205	total: 3.1s	remaining: 13.8s
# 184:	learn: 12115.4593325	total: 3.12s	remaining: 13.7s
# 185:	learn: 12065.1931034	total: 3.15s	remaining: 13.8s
# 186:	learn: 11994.2371455	total: 3.16s	remaining: 13.8s
# 187:	learn: 11911.0963586	total: 3.18s	remaining: 13.7s
# 188:	learn: 11840.0932017	total: 3.2s	remaining: 13.7s
# 189:	learn: 11829.2534500	total: 3.21s	remaining: 13.7s
# 190:	learn: 11789.7249828	total: 3.23s	remaining: 13.7s
# 191:	learn: 11730.2892516	total: 3.24s	remaining: 13.7s
# 192:	learn: 11679.4270324	total: 3.26s	remaining: 13.6s
# 193:	learn: 11624.7025948	total: 3.27s	remaining: 13.6s
# 194:	learn: 11579.3990989	total: 3.29s	remaining: 13.6s
# 195:	learn: 11573.6341927	total: 3.3s	remaining: 13.6s
# 196:	learn: 11516.0451521	total: 3.32s	remaining: 13.5s
# 197:	learn: 11484.7340317	total: 3.33s	remaining: 13.5s
# 198:	learn: 11429.7168597	total: 3.35s	remaining: 13.5s
# 199:	learn: 11375.7772202	total: 3.36s	remaining: 13.4s
# 200:	learn: 11327.9142545	total: 3.38s	remaining: 13.4s
# 201:	learn: 11262.5831167	total: 3.39s	remaining: 13.4s
# 202:	learn: 11204.0938845	total: 3.41s	remaining: 13.4s
# 203:	learn: 11172.2479011	total: 3.43s	remaining: 13.4s
# 204:	learn: 11123.1470707	total: 3.44s	remaining: 13.3s
# 205:	learn: 11075.9746857	total: 3.46s	remaining: 13.3s
# 206:	learn: 11005.5292452	total: 3.47s	remaining: 13.3s
# 207:	learn: 10981.5981385	total: 3.49s	remaining: 13.3s
# 208:	learn: 10976.1383202	total: 3.5s	remaining: 13.3s
# 209:	learn: 10913.4333555	total: 3.52s	remaining: 13.2s
# 210:	learn: 10867.3532631	total: 3.53s	remaining: 13.2s
# 211:	learn: 10773.8284156	total: 3.54s	remaining: 13.2s
# 212:	learn: 10737.7469296	total: 3.56s	remaining: 13.2s
# 213:	learn: 10671.6560105	total: 3.57s	remaining: 13.1s
# 214:	learn: 10556.1124324	total: 3.59s	remaining: 13.1s
# 215:	learn: 10453.4914941	total: 3.61s	remaining: 13.1s
# 216:	learn: 10414.8534042	total: 3.63s	remaining: 13.1s
# 217:	learn: 10328.6780364	total: 3.64s	remaining: 13.1s
# 218:	learn: 10272.5404568	total: 3.66s	remaining: 13s
# 219:	learn: 10230.0014866	total: 3.67s	remaining: 13s
# 220:	learn: 10183.7164109	total: 3.69s	remaining: 13s
# 221:	learn: 10143.6281967	total: 3.7s	remaining: 13s
# 222:	learn: 10095.6603646	total: 3.72s	remaining: 13s
# 223:	learn: 10054.3413977	total: 3.73s	remaining: 12.9s
# 224:	learn: 10023.0424742	total: 3.75s	remaining: 12.9s
# 225:	learn: 10009.1601578	total: 3.76s	remaining: 12.9s
# 226:	learn: 9964.8367923	total: 3.77s	remaining: 12.8s
# 227:	learn: 9947.2238748	total: 3.79s	remaining: 12.8s
# 228:	learn: 9871.9540589	total: 3.8s	remaining: 12.8s
# 229:	learn: 9836.6314437	total: 3.82s	remaining: 12.8s
# 230:	learn: 9787.8086476	total: 3.84s	remaining: 12.8s
# 231:	learn: 9772.1159595	total: 3.88s	remaining: 12.8s
# 232:	learn: 9750.6983901	total: 3.9s	remaining: 12.8s
# 233:	learn: 9704.5442505	total: 3.91s	remaining: 12.8s
# 234:	learn: 9661.5878533	total: 3.93s	remaining: 12.8s
# 235:	learn: 9631.6293496	total: 3.94s	remaining: 12.8s
# 236:	learn: 9610.0919814	total: 3.95s	remaining: 12.7s
# 237:	learn: 9574.1867899	total: 3.97s	remaining: 12.7s
# 238:	learn: 9544.4228274	total: 3.98s	remaining: 12.7s
# 239:	learn: 9498.8525476	total: 4s	remaining: 12.7s
# 240:	learn: 9475.9759697	total: 4.02s	remaining: 12.7s
# 241:	learn: 9431.6915704	total: 4.04s	remaining: 12.6s
# 242:	learn: 9402.9201944	total: 4.05s	remaining: 12.6s
# 243:	learn: 9369.8658648	total: 4.07s	remaining: 12.6s
# 244:	learn: 9362.2830116	total: 4.08s	remaining: 12.6s
# 245:	learn: 9330.9232687	total: 4.1s	remaining: 12.6s
# 246:	learn: 9282.9401881	total: 4.11s	remaining: 12.5s
# 247:	learn: 9251.8298667	total: 4.13s	remaining: 12.5s
# 248:	learn: 9207.6448765	total: 4.14s	remaining: 12.5s
# 249:	learn: 9173.9529052	total: 4.16s	remaining: 12.5s
# 250:	learn: 9149.0619211	total: 4.17s	remaining: 12.4s
# 251:	learn: 9116.8277550	total: 4.18s	remaining: 12.4s
# 252:	learn: 9089.0980224	total: 4.2s	remaining: 12.4s
# 253:	learn: 9069.6531291	total: 4.22s	remaining: 12.4s
# 254:	learn: 9030.5496040	total: 4.23s	remaining: 12.4s
# 255:	learn: 9009.4971769	total: 4.25s	remaining: 12.3s
# 256:	learn: 8992.8014073	total: 4.26s	remaining: 12.3s
# 257:	learn: 8972.0556734	total: 4.28s	remaining: 12.3s
# 258:	learn: 8919.7930487	total: 4.29s	remaining: 12.3s
# 259:	learn: 8911.3274489	total: 4.3s	remaining: 12.3s
# 260:	learn: 8893.1913644	total: 4.32s	remaining: 12.2s
# 261:	learn: 8873.8986514	total: 4.33s	remaining: 12.2s
# 262:	learn: 8868.7791637	total: 4.37s	remaining: 12.3s
# 263:	learn: 8854.4280733	total: 4.39s	remaining: 12.2s
# 264:	learn: 8845.0428876	total: 4.4s	remaining: 12.2s
# 265:	learn: 8833.0179900	total: 4.42s	remaining: 12.2s
# 266:	learn: 8826.3212307	total: 4.44s	remaining: 12.2s
# 267:	learn: 8758.0810644	total: 4.46s	remaining: 12.2s
# 268:	learn: 8732.7976584	total: 4.47s	remaining: 12.1s
# 269:	learn: 8709.6759834	total: 4.48s	remaining: 12.1s
# 270:	learn: 8684.1094141	total: 4.5s	remaining: 12.1s
# 271:	learn: 8659.4792828	total: 4.51s	remaining: 12.1s
# 272:	learn: 8624.3448197	total: 4.53s	remaining: 12.1s
# 273:	learn: 8620.9104596	total: 4.54s	remaining: 12s
# 274:	learn: 8575.5223241	total: 4.56s	remaining: 12s
# 275:	learn: 8542.6556375	total: 4.58s	remaining: 12s
# 276:	learn: 8522.4238988	total: 4.59s	remaining: 12s
# 277:	learn: 8515.9904385	total: 4.6s	remaining: 12s
# 278:	learn: 8495.9031393	total: 4.62s	remaining: 11.9s
# 279:	learn: 8463.4197406	total: 4.66s	remaining: 12s
# 280:	learn: 8462.2945038	total: 4.68s	remaining: 12s
# 281:	learn: 8453.8144296	total: 4.7s	remaining: 12s
# 282:	learn: 8452.7823171	total: 4.71s	remaining: 11.9s
# 283:	learn: 8399.7091143	total: 4.72s	remaining: 11.9s
# 284:	learn: 8347.7493489	total: 4.74s	remaining: 11.9s
# 285:	learn: 8315.3105014	total: 4.75s	remaining: 11.9s
# 286:	learn: 8298.3717450	total: 4.77s	remaining: 11.8s
# 287:	learn: 8252.1388895	total: 4.78s	remaining: 11.8s
# 288:	learn: 8226.4890279	total: 4.8s	remaining: 11.8s
# 289:	learn: 8204.3551090	total: 4.81s	remaining: 11.8s
# 290:	learn: 8163.5960447	total: 4.83s	remaining: 11.8s
# 291:	learn: 8131.6835384	total: 4.84s	remaining: 11.7s
# 292:	learn: 8076.4046369	total: 4.86s	remaining: 11.7s
# 293:	learn: 8057.3569578	total: 4.88s	remaining: 11.7s
# 294:	learn: 8034.4983589	total: 4.89s	remaining: 11.7s
# 295:	learn: 8005.5262094	total: 4.9s	remaining: 11.7s
# 296:	learn: 7982.7602339	total: 4.92s	remaining: 11.6s
# 297:	learn: 7962.6535799	total: 4.93s	remaining: 11.6s
# 298:	learn: 7925.5840017	total: 4.95s	remaining: 11.6s
# 299:	learn: 7920.0886940	total: 4.96s	remaining: 11.6s
# 300:	learn: 7896.2353511	total: 4.98s	remaining: 11.6s
# 301:	learn: 7878.3104881	total: 4.99s	remaining: 11.5s
# 302:	learn: 7854.1248985	total: 5.01s	remaining: 11.5s
# 303:	learn: 7841.4952164	total: 5.02s	remaining: 11.5s
# 304:	learn: 7810.4677774	total: 5.04s	remaining: 11.5s
# 305:	learn: 7795.3399347	total: 5.06s	remaining: 11.5s
# 306:	learn: 7767.8894843	total: 5.07s	remaining: 11.4s
# 307:	learn: 7748.4718436	total: 5.09s	remaining: 11.4s
# 308:	learn: 7734.7287853	total: 5.13s	remaining: 11.5s
# 309:	learn: 7705.5387936	total: 5.14s	remaining: 11.5s
# 310:	learn: 7679.8246949	total: 5.16s	remaining: 11.4s
# 311:	learn: 7663.4735490	total: 5.17s	remaining: 11.4s
# 312:	learn: 7634.1359532	total: 5.19s	remaining: 11.4s
# 313:	learn: 7603.0954890	total: 5.2s	remaining: 11.4s
# 314:	learn: 7586.9989549	total: 5.22s	remaining: 11.3s
# 315:	learn: 7567.9971567	total: 5.24s	remaining: 11.3s
# 316:	learn: 7546.5762852	total: 5.25s	remaining: 11.3s
# 317:	learn: 7532.3744288	total: 5.27s	remaining: 11.3s
# 318:	learn: 7510.3105176	total: 5.28s	remaining: 11.3s
# 319:	learn: 7495.0407737	total: 5.3s	remaining: 11.3s
# 320:	learn: 7487.5129284	total: 5.31s	remaining: 11.2s
# 321:	learn: 7452.7243994	total: 5.33s	remaining: 11.2s
# 322:	learn: 7445.8706188	total: 5.34s	remaining: 11.2s
# 323:	learn: 7430.2820951	total: 5.36s	remaining: 11.2s
# 324:	learn: 7412.3492040	total: 5.38s	remaining: 11.2s
# 325:	learn: 7394.6744274	total: 5.39s	remaining: 11.2s
# 326:	learn: 7393.1080057	total: 5.41s	remaining: 11.1s
# 327:	learn: 7374.0355422	total: 5.42s	remaining: 11.1s
# 328:	learn: 7370.2663831	total: 5.44s	remaining: 11.1s
# 329:	learn: 7363.9423019	total: 5.46s	remaining: 11.1s
# 330:	learn: 7351.0827907	total: 5.47s	remaining: 11.1s
# 331:	learn: 7350.3226699	total: 5.49s	remaining: 11s
# 332:	learn: 7336.5634511	total: 5.5s	remaining: 11s
# 333:	learn: 7324.2467414	total: 5.51s	remaining: 11s
# 334:	learn: 7304.8388789	total: 5.53s	remaining: 11s
# 335:	learn: 7304.0153262	total: 5.54s	remaining: 11s
# 336:	learn: 7301.0853862	total: 5.56s	remaining: 10.9s
# 337:	learn: 7283.6441365	total: 5.57s	remaining: 10.9s
# 338:	learn: 7259.4453258	total: 5.59s	remaining: 10.9s
# 339:	learn: 7234.3792765	total: 5.6s	remaining: 10.9s
# 340:	learn: 7209.7198052	total: 5.62s	remaining: 10.9s
# 341:	learn: 7182.0756803	total: 5.64s	remaining: 10.8s
# 342:	learn: 7179.3650507	total: 5.65s	remaining: 10.8s
# 343:	learn: 7164.5603660	total: 5.67s	remaining: 10.8s
# 344:	learn: 7145.4106020	total: 5.68s	remaining: 10.8s
# 345:	learn: 7143.8918325	total: 5.7s	remaining: 10.8s
# 346:	learn: 7122.5011919	total: 5.71s	remaining: 10.7s
# 347:	learn: 7113.2887058	total: 5.72s	remaining: 10.7s
# 348:	learn: 7099.3068805	total: 5.74s	remaining: 10.7s
# 349:	learn: 7083.4683191	total: 5.75s	remaining: 10.7s
# 350:	learn: 7060.3446740	total: 5.77s	remaining: 10.7s
# 351:	learn: 7054.2212146	total: 5.78s	remaining: 10.6s
# 352:	learn: 7043.5943850	total: 5.8s	remaining: 10.6s
# 353:	learn: 7035.8080199	total: 5.81s	remaining: 10.6s
# 354:	learn: 7013.1890929	total: 5.83s	remaining: 10.6s
# 355:	learn: 6994.9552782	total: 5.84s	remaining: 10.6s
# 356:	learn: 6987.0362841	total: 5.86s	remaining: 10.6s
# 357:	learn: 6971.3324689	total: 5.88s	remaining: 10.5s
# 358:	learn: 6951.7724570	total: 5.89s	remaining: 10.5s
# 359:	learn: 6929.3914362	total: 5.91s	remaining: 10.5s
# 360:	learn: 6912.5572150	total: 5.92s	remaining: 10.5s
# 361:	learn: 6901.2955641	total: 5.93s	remaining: 10.5s
# 362:	learn: 6879.6311514	total: 5.95s	remaining: 10.4s
# 363:	learn: 6861.7442086	total: 5.96s	remaining: 10.4s
# 364:	learn: 6844.3620591	total: 5.98s	remaining: 10.4s
# 365:	learn: 6829.7052325	total: 5.99s	remaining: 10.4s
# 366:	learn: 6820.8058385	total: 6.01s	remaining: 10.4s
# 367:	learn: 6818.1184734	total: 6.02s	remaining: 10.3s
# 368:	learn: 6796.9697217	total: 6.04s	remaining: 10.3s
# 369:	learn: 6777.6989577	total: 6.06s	remaining: 10.3s
# 370:	learn: 6762.7777952	total: 6.07s	remaining: 10.3s
# 371:	learn: 6741.8231537	total: 6.08s	remaining: 10.3s
# 372:	learn: 6732.3064440	total: 6.1s	remaining: 10.3s
# 373:	learn: 6724.0658730	total: 6.12s	remaining: 10.2s
# 374:	learn: 6709.2312697	total: 6.13s	remaining: 10.2s
# 375:	learn: 6699.8915407	total: 6.14s	remaining: 10.2s
# 376:	learn: 6690.3300662	total: 6.16s	remaining: 10.2s
# 377:	learn: 6678.6881631	total: 6.17s	remaining: 10.2s
# 378:	learn: 6654.4508990	total: 6.19s	remaining: 10.1s
# 379:	learn: 6641.2259138	total: 6.2s	remaining: 10.1s
# 380:	learn: 6627.8781917	total: 6.22s	remaining: 10.1s
# 381:	learn: 6618.7400951	total: 6.24s	remaining: 10.1s
# 382:	learn: 6592.0846274	total: 6.25s	remaining: 10.1s
# 383:	learn: 6577.5821382	total: 6.27s	remaining: 10.1s
# 384:	learn: 6566.7722378	total: 6.28s	remaining: 10s
# 385:	learn: 6557.6301923	total: 6.3s	remaining: 10s
# 386:	learn: 6553.8773580	total: 6.31s	remaining: 10s
# 387:	learn: 6522.7495415	total: 6.33s	remaining: 9.98s
# 388:	learn: 6506.9319166	total: 6.34s	remaining: 9.96s
# 389:	learn: 6491.4972185	total: 6.36s	remaining: 9.94s
# 390:	learn: 6487.5178491	total: 6.37s	remaining: 9.93s
# 391:	learn: 6482.0083825	total: 6.39s	remaining: 9.91s
# 392:	learn: 6481.4146943	total: 6.4s	remaining: 9.89s
# 393:	learn: 6469.3186474	total: 6.42s	remaining: 9.87s
# 394:	learn: 6458.6591585	total: 6.43s	remaining: 9.86s
# 395:	learn: 6439.0019192	total: 6.45s	remaining: 9.84s
# 396:	learn: 6423.3897521	total: 6.46s	remaining: 9.82s
# 397:	learn: 6417.3185398	total: 6.48s	remaining: 9.8s
# 398:	learn: 6408.4249999	total: 6.5s	remaining: 9.79s
# 399:	learn: 6400.5572547	total: 6.51s	remaining: 9.77s
# 400:	learn: 6381.3743397	total: 6.53s	remaining: 9.75s
# 401:	learn: 6353.9189890	total: 6.54s	remaining: 9.73s
# 402:	learn: 6349.8733019	total: 6.56s	remaining: 9.71s
# 403:	learn: 6349.4427378	total: 6.57s	remaining: 9.7s
# 404:	learn: 6335.7512864	total: 6.59s	remaining: 9.68s
# 405:	learn: 6325.4125863	total: 6.6s	remaining: 9.66s
# 406:	learn: 6318.9254269	total: 6.62s	remaining: 9.64s
# 407:	learn: 6284.1888279	total: 6.63s	remaining: 9.62s
# 408:	learn: 6279.9659247	total: 6.65s	remaining: 9.61s
# 409:	learn: 6269.4787276	total: 6.67s	remaining: 9.59s
# 410:	learn: 6265.9619339	total: 6.68s	remaining: 9.57s
# 411:	learn: 6252.6546371	total: 6.7s	remaining: 9.56s
# 412:	learn: 6248.9327144	total: 6.71s	remaining: 9.54s
# 413:	learn: 6223.3258955	total: 6.73s	remaining: 9.52s
# 414:	learn: 6209.2763370	total: 6.77s	remaining: 9.54s
# 415:	learn: 6200.5552741	total: 6.79s	remaining: 9.53s
# 416:	learn: 6188.8236613	total: 6.8s	remaining: 9.51s
# 417:	learn: 6177.5136194	total: 6.82s	remaining: 9.5s
# 418:	learn: 6172.4364351	total: 6.84s	remaining: 9.48s
# 419:	learn: 6152.9284425	total: 6.86s	remaining: 9.47s
# 420:	learn: 6135.6780336	total: 6.87s	remaining: 9.45s
# 421:	learn: 6130.8681117	total: 6.88s	remaining: 9.43s
# 422:	learn: 6122.3039851	total: 6.9s	remaining: 9.41s
# 423:	learn: 6100.4388163	total: 6.94s	remaining: 9.43s
# 424:	learn: 6096.8433850	total: 6.97s	remaining: 9.42s
# 425:	learn: 6090.1229867	total: 6.98s	remaining: 9.41s
# 426:	learn: 6066.8594414	total: 7s	remaining: 9.39s
# 427:	learn: 6052.3645094	total: 7.01s	remaining: 9.37s
# 428:	learn: 6045.0660847	total: 7.03s	remaining: 9.35s
# 429:	learn: 6029.8648702	total: 7.04s	remaining: 9.34s
# 430:	learn: 6029.7649413	total: 7.06s	remaining: 9.32s
# 431:	learn: 6023.4688622	total: 7.08s	remaining: 9.3s
# 432:	learn: 6010.7529905	total: 7.09s	remaining: 9.29s
# 433:	learn: 6001.3421529	total: 7.11s	remaining: 9.27s
# 434:	learn: 5999.6490851	total: 7.12s	remaining: 9.25s
# 435:	learn: 5977.4529205	total: 7.13s	remaining: 9.23s
# 436:	learn: 5969.3652503	total: 7.15s	remaining: 9.21s
# 437:	learn: 5952.3724021	total: 7.17s	remaining: 9.19s
# 438:	learn: 5941.7621330	total: 7.18s	remaining: 9.18s
# 439:	learn: 5931.6621682	total: 7.19s	remaining: 9.16s
# 440:	learn: 5923.7589416	total: 7.21s	remaining: 9.14s
# 441:	learn: 5920.9838016	total: 7.22s	remaining: 9.12s
# 442:	learn: 5915.9901343	total: 7.24s	remaining: 9.1s
# 443:	learn: 5911.7598122	total: 7.26s	remaining: 9.09s
# 444:	learn: 5907.6823012	total: 7.27s	remaining: 9.07s
# 445:	learn: 5893.7488533	total: 7.29s	remaining: 9.05s
# 446:	learn: 5890.4358261	total: 7.3s	remaining: 9.04s
# 447:	learn: 5880.3240938	total: 7.33s	remaining: 9.03s
# 448:	learn: 5866.0926089	total: 7.35s	remaining: 9.02s
# 449:	learn: 5856.2542656	total: 7.36s	remaining: 9s
# 450:	learn: 5843.4477806	total: 7.38s	remaining: 8.98s
# 451:	learn: 5839.1989939	total: 7.39s	remaining: 8.96s
# 452:	learn: 5833.6795762	total: 7.41s	remaining: 8.94s
# 453:	learn: 5827.3581475	total: 7.42s	remaining: 8.92s
# 454:	learn: 5824.1517331	total: 7.44s	remaining: 8.91s
# 455:	learn: 5822.1197643	total: 7.46s	remaining: 8.89s
# 456:	learn: 5811.7396789	total: 7.47s	remaining: 8.88s
# 457:	learn: 5808.6648313	total: 7.49s	remaining: 8.86s
# 458:	learn: 5804.0104673	total: 7.5s	remaining: 8.84s
# 459:	learn: 5794.5594072	total: 7.52s	remaining: 8.82s
# 460:	learn: 5788.0615473	total: 7.53s	remaining: 8.81s
# 461:	learn: 5780.7221020	total: 7.55s	remaining: 8.79s
# 462:	learn: 5776.7767476	total: 7.56s	remaining: 8.77s
# 463:	learn: 5770.7495148	total: 7.58s	remaining: 8.76s
# 464:	learn: 5767.2952743	total: 7.59s	remaining: 8.74s
# 465:	learn: 5758.1681918	total: 7.61s	remaining: 8.72s
# 466:	learn: 5753.5208482	total: 7.62s	remaining: 8.7s
# 467:	learn: 5741.1783160	total: 7.64s	remaining: 8.69s
# 468:	learn: 5727.8209961	total: 7.66s	remaining: 8.67s
# 469:	learn: 5710.4761538	total: 7.67s	remaining: 8.65s
# 470:	learn: 5705.3384650	total: 7.69s	remaining: 8.64s
# 471:	learn: 5699.5625290	total: 7.7s	remaining: 8.62s
# 472:	learn: 5693.4495538	total: 7.72s	remaining: 8.6s
# 473:	learn: 5688.5849199	total: 7.73s	remaining: 8.58s
# 474:	learn: 5686.5055280	total: 7.75s	remaining: 8.56s
# 475:	learn: 5675.2084173	total: 7.76s	remaining: 8.54s
# 476:	learn: 5651.9153544	total: 7.78s	remaining: 8.53s
# 477:	learn: 5636.7519371	total: 7.79s	remaining: 8.51s
# 478:	learn: 5632.1374789	total: 7.81s	remaining: 8.49s
# 479:	learn: 5625.9778456	total: 7.82s	remaining: 8.47s
# 480:	learn: 5625.4540312	total: 7.83s	remaining: 8.45s
# 481:	learn: 5622.7673362	total: 7.85s	remaining: 8.44s
# 482:	learn: 5618.1786493	total: 7.87s	remaining: 8.42s
# 483:	learn: 5615.0574425	total: 7.88s	remaining: 8.41s
# 484:	learn: 5611.9350504	total: 7.9s	remaining: 8.39s
# 485:	learn: 5603.2593372	total: 7.92s	remaining: 8.37s
# 486:	learn: 5598.6745331	total: 7.93s	remaining: 8.35s
# 487:	learn: 5590.7894693	total: 7.94s	remaining: 8.34s
# 488:	learn: 5577.8038108	total: 7.96s	remaining: 8.32s
# 489:	learn: 5568.6675084	total: 7.97s	remaining: 8.3s
# 490:	learn: 5557.8719479	total: 7.99s	remaining: 8.28s
# 491:	learn: 5555.7990558	total: 8s	remaining: 8.26s
# 492:	learn: 5551.5348713	total: 8.02s	remaining: 8.24s
# 493:	learn: 5541.1021387	total: 8.03s	remaining: 8.23s
# 494:	learn: 5530.1650359	total: 8.05s	remaining: 8.21s
# 495:	learn: 5525.8326912	total: 8.07s	remaining: 8.2s
# 496:	learn: 5522.4268246	total: 8.08s	remaining: 8.18s
# 497:	learn: 5511.1143396	total: 8.1s	remaining: 8.16s
# 498:	learn: 5511.0956056	total: 8.11s	remaining: 8.14s
# 499:	learn: 5506.7174428	total: 8.13s	remaining: 8.13s
# 500:	learn: 5475.9976454	total: 8.14s	remaining: 8.11s
# 501:	learn: 5472.8272262	total: 8.15s	remaining: 8.09s
# 502:	learn: 5470.1314579	total: 8.17s	remaining: 8.07s
# 503:	learn: 5460.8140314	total: 8.19s	remaining: 8.05s
# 504:	learn: 5456.5789355	total: 8.2s	remaining: 8.04s
# 505:	learn: 5448.6645772	total: 8.21s	remaining: 8.02s
# 506:	learn: 5439.2937102	total: 8.23s	remaining: 8s
# 507:	learn: 5436.5523611	total: 8.25s	remaining: 7.99s
# 508:	learn: 5428.3758229	total: 8.26s	remaining: 7.97s
# 509:	learn: 5419.3846927	total: 8.28s	remaining: 7.96s
# 510:	learn: 5414.2304936	total: 8.3s	remaining: 7.94s
# 511:	learn: 5404.8574158	total: 8.31s	remaining: 7.92s
# 512:	learn: 5392.0132538	total: 8.33s	remaining: 7.91s
# 513:	learn: 5383.7423013	total: 8.34s	remaining: 7.89s
# 514:	learn: 5378.3098884	total: 8.36s	remaining: 7.87s
# 515:	learn: 5369.5697980	total: 8.37s	remaining: 7.85s
# 516:	learn: 5362.4657586	total: 8.39s	remaining: 7.84s
# 517:	learn: 5355.0692987	total: 8.4s	remaining: 7.82s
# 518:	learn: 5342.1777710	total: 8.42s	remaining: 7.8s
# 519:	learn: 5338.9738402	total: 8.43s	remaining: 7.78s
# 520:	learn: 5333.4783854	total: 8.45s	remaining: 7.77s
# 521:	learn: 5323.7562200	total: 8.47s	remaining: 7.75s
# 522:	learn: 5302.5525785	total: 8.48s	remaining: 7.74s
# 523:	learn: 5291.2637280	total: 8.5s	remaining: 7.72s
# 524:	learn: 5285.1215494	total: 8.51s	remaining: 7.7s
# 525:	learn: 5257.9612394	total: 8.53s	remaining: 7.69s
# 526:	learn: 5248.8597881	total: 8.54s	remaining: 7.67s
# 527:	learn: 5238.5810775	total: 8.56s	remaining: 7.65s
# 528:	learn: 5236.4857667	total: 8.57s	remaining: 7.63s
# 529:	learn: 5227.8590366	total: 8.59s	remaining: 7.62s
# 530:	learn: 5225.9831031	total: 8.6s	remaining: 7.6s
# 531:	learn: 5219.5643335	total: 8.62s	remaining: 7.58s
# 532:	learn: 5211.5580733	total: 8.63s	remaining: 7.56s
# 533:	learn: 5203.0408966	total: 8.65s	remaining: 7.55s
# 534:	learn: 5194.3076273	total: 8.66s	remaining: 7.53s
# 535:	learn: 5190.3574188	total: 8.68s	remaining: 7.51s
# 536:	learn: 5180.1856553	total: 8.7s	remaining: 7.5s
# 537:	learn: 5172.4066833	total: 8.71s	remaining: 7.48s
# 538:	learn: 5162.7110550	total: 8.73s	remaining: 7.46s
# 539:	learn: 5152.0167796	total: 8.74s	remaining: 7.45s
# 540:	learn: 5145.7524525	total: 8.76s	remaining: 7.43s
# 541:	learn: 5144.5981031	total: 8.77s	remaining: 7.41s
# 542:	learn: 5141.0246076	total: 8.79s	remaining: 7.39s
# 543:	learn: 5133.7350354	total: 8.8s	remaining: 7.38s
# 544:	learn: 5129.6139104	total: 8.81s	remaining: 7.36s
# 545:	learn: 5127.1273542	total: 8.83s	remaining: 7.34s
# 546:	learn: 5126.6684233	total: 8.85s	remaining: 7.33s
# 547:	learn: 5118.0830654	total: 8.86s	remaining: 7.31s
# 548:	learn: 5109.2914442	total: 8.88s	remaining: 7.29s
# 549:	learn: 5107.6582936	total: 8.89s	remaining: 7.28s
# 550:	learn: 5104.4067955	total: 8.91s	remaining: 7.26s
# 551:	learn: 5101.9837677	total: 8.93s	remaining: 7.24s
# 552:	learn: 5096.6200345	total: 8.94s	remaining: 7.23s
# 553:	learn: 5081.1431545	total: 8.95s	remaining: 7.21s
# 554:	learn: 5067.6990502	total: 8.97s	remaining: 7.19s
# 555:	learn: 5062.3355050	total: 8.98s	remaining: 7.17s
# 556:	learn: 5052.0640104	total: 9s	remaining: 7.16s
# 557:	learn: 5046.2389095	total: 9.01s	remaining: 7.14s
# 558:	learn: 5038.7749014	total: 9.03s	remaining: 7.12s
# 559:	learn: 5010.4312828	total: 9.04s	remaining: 7.1s
# 560:	learn: 5007.9040975	total: 9.06s	remaining: 7.09s
# 561:	learn: 5003.8352589	total: 9.07s	remaining: 7.07s
# 562:	learn: 5000.7981662	total: 9.09s	remaining: 7.06s
# 563:	learn: 4995.3292805	total: 9.11s	remaining: 7.04s
# 564:	learn: 4988.1344930	total: 9.14s	remaining: 7.04s
# 565:	learn: 4978.2724815	total: 9.16s	remaining: 7.02s
# 566:	learn: 4970.9610217	total: 9.17s	remaining: 7s
# 567:	learn: 4967.3850986	total: 9.19s	remaining: 6.99s
# 568:	learn: 4956.5225336	total: 9.2s	remaining: 6.97s
# 569:	learn: 4950.1977383	total: 9.21s	remaining: 6.95s
# 570:	learn: 4944.0611714	total: 9.23s	remaining: 6.93s
# 571:	learn: 4937.1121730	total: 9.24s	remaining: 6.92s
# 572:	learn: 4924.4405106	total: 9.26s	remaining: 6.9s
# 573:	learn: 4921.9029131	total: 9.28s	remaining: 6.88s
# 574:	learn: 4913.0983649	total: 9.29s	remaining: 6.87s
# 575:	learn: 4906.4568538	total: 9.31s	remaining: 6.85s
# 576:	learn: 4900.6969705	total: 9.33s	remaining: 6.84s
# 577:	learn: 4897.3331769	total: 9.34s	remaining: 6.82s
# 578:	learn: 4892.9629109	total: 9.36s	remaining: 6.8s
# 579:	learn: 4891.1816352	total: 9.37s	remaining: 6.79s
# 580:	learn: 4887.0650420	total: 9.38s	remaining: 6.77s
# 581:	learn: 4877.9769219	total: 9.4s	remaining: 6.75s
# 582:	learn: 4872.1588116	total: 9.41s	remaining: 6.73s
# 583:	learn: 4867.4685201	total: 9.46s	remaining: 6.74s
# 584:	learn: 4862.2550918	total: 9.48s	remaining: 6.72s
# 585:	learn: 4854.8840695	total: 9.49s	remaining: 6.71s
# 586:	learn: 4851.0389707	total: 9.51s	remaining: 6.69s
# 587:	learn: 4842.0889319	total: 9.53s	remaining: 6.67s
# 588:	learn: 4836.8627759	total: 9.54s	remaining: 6.66s
# 589:	learn: 4833.4120829	total: 9.56s	remaining: 6.64s
# 590:	learn: 4827.4975638	total: 9.57s	remaining: 6.62s
# 591:	learn: 4825.0346389	total: 9.59s	remaining: 6.61s
# 592:	learn: 4820.8341607	total: 9.6s	remaining: 6.59s
# 593:	learn: 4817.6812087	total: 9.62s	remaining: 6.57s
# 594:	learn: 4809.4960269	total: 9.63s	remaining: 6.55s
# 595:	learn: 4802.7524737	total: 9.65s	remaining: 6.54s
# 596:	learn: 4795.3609604	total: 9.66s	remaining: 6.52s
# 597:	learn: 4788.2729736	total: 9.68s	remaining: 6.51s
# 598:	learn: 4780.9555770	total: 9.69s	remaining: 6.49s
# 599:	learn: 4773.6054770	total: 9.71s	remaining: 6.47s
# 600:	learn: 4770.4675960	total: 9.72s	remaining: 6.45s
# 601:	learn: 4762.8710637	total: 9.74s	remaining: 6.44s
# 602:	learn: 4755.8247108	total: 9.75s	remaining: 6.42s
# 603:	learn: 4748.3835939	total: 9.77s	remaining: 6.4s
# 604:	learn: 4741.1432118	total: 9.79s	remaining: 6.39s
# 605:	learn: 4736.0672858	total: 9.81s	remaining: 6.38s
# 606:	learn: 4728.8450243	total: 9.83s	remaining: 6.36s
# 607:	learn: 4722.9827160	total: 9.85s	remaining: 6.35s
# 608:	learn: 4721.1577181	total: 9.87s	remaining: 6.33s
# 609:	learn: 4716.0004856	total: 9.88s	remaining: 6.32s
# 610:	learn: 4715.1164274	total: 9.9s	remaining: 6.3s
# 611:	learn: 4713.9773732	total: 9.91s	remaining: 6.28s
# 612:	learn: 4704.4119002	total: 9.93s	remaining: 6.27s
# 613:	learn: 4699.1930373	total: 9.94s	remaining: 6.25s
# 614:	learn: 4690.0054855	total: 9.96s	remaining: 6.23s
# 615:	learn: 4684.6646959	total: 9.97s	remaining: 6.21s
# 616:	learn: 4678.7897032	total: 9.98s	remaining: 6.2s
# 617:	learn: 4673.1960739	total: 10s	remaining: 6.18s
# 618:	learn: 4670.3169706	total: 10s	remaining: 6.16s
# 619:	learn: 4666.3359816	total: 10s	remaining: 6.15s
# 620:	learn: 4658.7154386	total: 10s	remaining: 6.13s
# 621:	learn: 4655.8584299	total: 10.1s	remaining: 6.12s
# 622:	learn: 4651.5501157	total: 10.1s	remaining: 6.1s
# 623:	learn: 4647.9502099	total: 10.1s	remaining: 6.08s
# 624:	learn: 4646.2858368	total: 10.1s	remaining: 6.07s
# 625:	learn: 4637.3204272	total: 10.1s	remaining: 6.05s
# 626:	learn: 4633.2253766	total: 10.1s	remaining: 6.03s
# 627:	learn: 4630.4412234	total: 10.2s	remaining: 6.02s
# 628:	learn: 4628.5702543	total: 10.2s	remaining: 6s
# 629:	learn: 4624.0591013	total: 10.2s	remaining: 5.98s
# 630:	learn: 4622.4911016	total: 10.2s	remaining: 5.96s
# 631:	learn: 4613.3743141	total: 10.2s	remaining: 5.95s
# 632:	learn: 4608.6210043	total: 10.2s	remaining: 5.93s
# 633:	learn: 4607.5701364	total: 10.2s	remaining: 5.91s
# 634:	learn: 4602.6411100	total: 10.3s	remaining: 5.9s
# 635:	learn: 4600.8455491	total: 10.3s	remaining: 5.88s
# 636:	learn: 4599.2679162	total: 10.3s	remaining: 5.87s
# 637:	learn: 4594.5615383	total: 10.3s	remaining: 5.86s
# 638:	learn: 4584.4649043	total: 10.3s	remaining: 5.85s
# 639:	learn: 4579.8162271	total: 10.4s	remaining: 5.83s
# 640:	learn: 4579.3285171	total: 10.4s	remaining: 5.82s
# 641:	learn: 4573.4069698	total: 10.4s	remaining: 5.8s
# 642:	learn: 4570.0488877	total: 10.4s	remaining: 5.78s
# 643:	learn: 4565.5565582	total: 10.4s	remaining: 5.76s
# 644:	learn: 4560.0021849	total: 10.4s	remaining: 5.75s
# 645:	learn: 4554.0990159	total: 10.5s	remaining: 5.73s
# 646:	learn: 4552.6547646	total: 10.5s	remaining: 5.71s
# 647:	learn: 4547.5168505	total: 10.5s	remaining: 5.7s
# 648:	learn: 4542.8402955	total: 10.5s	remaining: 5.68s
# 649:	learn: 4538.6348173	total: 10.5s	remaining: 5.67s
# 650:	learn: 4534.3349229	total: 10.5s	remaining: 5.65s
# 651:	learn: 4530.7343255	total: 10.6s	remaining: 5.63s
# 652:	learn: 4528.5021028	total: 10.6s	remaining: 5.62s
# 653:	learn: 4524.2309746	total: 10.6s	remaining: 5.6s
# 654:	learn: 4521.2098387	total: 10.6s	remaining: 5.58s
# 655:	learn: 4511.5831419	total: 10.6s	remaining: 5.57s
# 656:	learn: 4507.0417781	total: 10.6s	remaining: 5.55s
# 657:	learn: 4505.5619147	total: 10.6s	remaining: 5.53s
# 658:	learn: 4502.6132685	total: 10.7s	remaining: 5.51s
# 659:	learn: 4493.8105474	total: 10.7s	remaining: 5.5s
# 660:	learn: 4492.2014480	total: 10.7s	remaining: 5.48s
# 661:	learn: 4488.8204695	total: 10.7s	remaining: 5.46s
# 662:	learn: 4485.2278828	total: 10.7s	remaining: 5.45s
# 663:	learn: 4481.6010298	total: 10.7s	remaining: 5.43s
# 664:	learn: 4479.9567994	total: 10.8s	remaining: 5.42s
# 665:	learn: 4477.4273558	total: 10.8s	remaining: 5.4s
# 666:	learn: 4474.7794941	total: 10.8s	remaining: 5.38s
# 667:	learn: 4473.8147151	total: 10.8s	remaining: 5.37s
# 668:	learn: 4471.0571589	total: 10.8s	remaining: 5.35s
# 669:	learn: 4469.9400388	total: 10.8s	remaining: 5.33s
# 670:	learn: 4468.8727289	total: 10.8s	remaining: 5.32s
# 671:	learn: 4465.0186309	total: 10.9s	remaining: 5.3s
# 672:	learn: 4462.8382866	total: 10.9s	remaining: 5.28s
# 673:	learn: 4451.6276303	total: 10.9s	remaining: 5.27s
# 674:	learn: 4448.6989142	total: 10.9s	remaining: 5.25s
# 675:	learn: 4443.5324884	total: 10.9s	remaining: 5.24s
# 676:	learn: 4439.3288905	total: 10.9s	remaining: 5.22s
# 677:	learn: 4434.4854649	total: 11s	remaining: 5.2s
# 678:	learn: 4432.9173365	total: 11s	remaining: 5.18s
# 679:	learn: 4427.2020538	total: 11s	remaining: 5.17s
# 680:	learn: 4422.1106643	total: 11s	remaining: 5.15s
# 681:	learn: 4419.7913931	total: 11s	remaining: 5.13s
# 682:	learn: 4417.6373201	total: 11s	remaining: 5.12s
# 683:	learn: 4412.8029334	total: 11s	remaining: 5.1s
# 684:	learn: 4410.4134518	total: 11.1s	remaining: 5.08s
# 685:	learn: 4405.4222984	total: 11.1s	remaining: 5.07s
# 686:	learn: 4401.8630284	total: 11.1s	remaining: 5.05s
# 687:	learn: 4400.5147589	total: 11.1s	remaining: 5.04s
# 688:	learn: 4395.7151415	total: 11.1s	remaining: 5.02s
# 689:	learn: 4392.2708492	total: 11.1s	remaining: 5.01s
# 690:	learn: 4388.5522943	total: 11.2s	remaining: 4.99s
# 691:	learn: 4385.9377563	total: 11.2s	remaining: 4.97s
# 692:	learn: 4376.4853101	total: 11.2s	remaining: 4.96s
# 693:	learn: 4372.3115853	total: 11.2s	remaining: 4.94s
# 694:	learn: 4368.3248857	total: 11.2s	remaining: 4.92s
# 695:	learn: 4363.2853617	total: 11.3s	remaining: 4.91s
# 696:	learn: 4361.3631338	total: 11.3s	remaining: 4.9s
# 697:	learn: 4358.8050440	total: 11.3s	remaining: 4.88s
# 698:	learn: 4356.5153357	total: 11.3s	remaining: 4.87s
# 699:	learn: 4352.4931567	total: 11.3s	remaining: 4.85s
# 700:	learn: 4348.3608142	total: 11.4s	remaining: 4.84s
# 701:	learn: 4345.3585560	total: 11.4s	remaining: 4.83s
# 702:	learn: 4344.0588450	total: 11.4s	remaining: 4.81s
# 703:	learn: 4342.2600747	total: 11.4s	remaining: 4.8s
# 704:	learn: 4339.6857422	total: 11.4s	remaining: 4.78s
# 705:	learn: 4332.0969319	total: 11.4s	remaining: 4.76s
# 706:	learn: 4330.7190185	total: 11.5s	remaining: 4.75s
# 707:	learn: 4326.3871280	total: 11.5s	remaining: 4.73s
# 708:	learn: 4320.6560703	total: 11.5s	remaining: 4.71s
# 709:	learn: 4315.2014987	total: 11.5s	remaining: 4.7s
# 710:	learn: 4312.1938610	total: 11.5s	remaining: 4.68s
# 711:	learn: 4309.9647290	total: 11.5s	remaining: 4.67s
# 712:	learn: 4307.9811661	total: 11.6s	remaining: 4.65s
# 713:	learn: 4307.0828305	total: 11.6s	remaining: 4.63s
# 714:	learn: 4303.5260584	total: 11.6s	remaining: 4.62s
# 715:	learn: 4300.9201543	total: 11.6s	remaining: 4.61s
# 716:	learn: 4294.3450656	total: 11.6s	remaining: 4.59s
# 717:	learn: 4285.3917310	total: 11.6s	remaining: 4.57s
# 718:	learn: 4283.9704190	total: 11.7s	remaining: 4.56s
# 719:	learn: 4283.6108118	total: 11.7s	remaining: 4.54s
# 720:	learn: 4280.3586732	total: 11.7s	remaining: 4.52s
# 721:	learn: 4273.6091107	total: 11.7s	remaining: 4.51s
# 722:	learn: 4269.6301866	total: 11.7s	remaining: 4.49s
# 723:	learn: 4268.7661675	total: 11.7s	remaining: 4.48s
# 724:	learn: 4265.7694076	total: 11.8s	remaining: 4.46s
# 725:	learn: 4262.2125506	total: 11.8s	remaining: 4.44s
# 726:	learn: 4260.1379895	total: 11.8s	remaining: 4.42s
# 727:	learn: 4259.6597644	total: 11.8s	remaining: 4.41s
# 728:	learn: 4259.1379178	total: 11.8s	remaining: 4.39s
# 729:	learn: 4256.6294207	total: 11.9s	remaining: 4.39s
# 730:	learn: 4254.0971555	total: 11.9s	remaining: 4.37s
# 731:	learn: 4253.7903543	total: 11.9s	remaining: 4.36s
# 732:	learn: 4250.0737477	total: 11.9s	remaining: 4.34s
# 733:	learn: 4243.1758088	total: 11.9s	remaining: 4.32s
# 734:	learn: 4242.1539085	total: 11.9s	remaining: 4.31s
# 735:	learn: 4240.2536385	total: 12s	remaining: 4.29s
# 736:	learn: 4237.7650342	total: 12s	remaining: 4.27s
# 737:	learn: 4232.9620112	total: 12s	remaining: 4.26s
# 738:	learn: 4228.1436381	total: 12s	remaining: 4.24s
# 739:	learn: 4215.2983809	total: 12s	remaining: 4.22s
# 740:	learn: 4215.1790038	total: 12s	remaining: 4.21s
# 741:	learn: 4214.9297633	total: 12.1s	remaining: 4.19s
# 742:	learn: 4214.7102512	total: 12.1s	remaining: 4.17s
# 743:	learn: 4212.3033980	total: 12.1s	remaining: 4.16s
# 744:	learn: 4210.2286999	total: 12.1s	remaining: 4.14s
# 745:	learn: 4207.2754914	total: 12.1s	remaining: 4.12s
# 746:	learn: 4205.1785778	total: 12.1s	remaining: 4.11s
# 747:	learn: 4204.5452737	total: 12.2s	remaining: 4.1s
# 748:	learn: 4181.9714493	total: 12.2s	remaining: 4.08s
# 749:	learn: 4178.1845560	total: 12.2s	remaining: 4.07s
# 750:	learn: 4175.3047310	total: 12.2s	remaining: 4.05s
# 751:	learn: 4173.8013986	total: 12.2s	remaining: 4.03s
# 752:	learn: 4170.3063273	total: 12.2s	remaining: 4.02s
# 753:	learn: 4168.8931100	total: 12.3s	remaining: 4s
# 754:	learn: 4167.9735366	total: 12.3s	remaining: 3.98s
# 755:	learn: 4166.0700741	total: 12.3s	remaining: 3.97s
# 756:	learn: 4164.5334535	total: 12.3s	remaining: 3.95s
# 757:	learn: 4157.8944826	total: 12.3s	remaining: 3.94s
# 758:	learn: 4153.3456842	total: 12.3s	remaining: 3.92s
# 759:	learn: 4149.4626753	total: 12.4s	remaining: 3.9s
# 760:	learn: 4147.9806831	total: 12.4s	remaining: 3.89s
# 761:	learn: 4146.3828132	total: 12.4s	remaining: 3.87s
# 762:	learn: 4144.6854699	total: 12.4s	remaining: 3.85s
# 763:	learn: 4139.9476834	total: 12.4s	remaining: 3.84s
# 764:	learn: 4139.6042738	total: 12.4s	remaining: 3.82s
# 765:	learn: 4139.2924460	total: 12.4s	remaining: 3.8s
# 766:	learn: 4138.4990344	total: 12.5s	remaining: 3.79s
# 767:	learn: 4135.3695480	total: 12.5s	remaining: 3.77s
# 768:	learn: 4130.6347706	total: 12.5s	remaining: 3.75s
# 769:	learn: 4128.2236319	total: 12.5s	remaining: 3.74s
# 770:	learn: 4128.2135173	total: 12.5s	remaining: 3.73s
# 771:	learn: 4128.1211024	total: 12.6s	remaining: 3.71s
# 772:	learn: 4126.6166588	total: 12.6s	remaining: 3.69s
# 773:	learn: 4122.7164848	total: 12.6s	remaining: 3.68s
# 774:	learn: 4118.7427736	total: 12.6s	remaining: 3.66s
# 775:	learn: 4118.3191884	total: 12.6s	remaining: 3.64s
# 776:	learn: 4117.2504436	total: 12.6s	remaining: 3.63s
# 777:	learn: 4115.8926257	total: 12.7s	remaining: 3.61s
# 778:	learn: 4115.0434634	total: 12.7s	remaining: 3.59s
# 779:	learn: 4111.6609953	total: 12.7s	remaining: 3.58s
# 780:	learn: 4109.7559260	total: 12.7s	remaining: 3.56s
# 781:	learn: 4108.9778509	total: 12.7s	remaining: 3.55s
# 782:	learn: 4106.1999725	total: 12.7s	remaining: 3.53s
# 783:	learn: 4104.1030650	total: 12.8s	remaining: 3.51s
# 784:	learn: 4102.9230679	total: 12.8s	remaining: 3.5s
# 785:	learn: 4100.2373469	total: 12.8s	remaining: 3.48s
# 786:	learn: 4098.8297060	total: 12.8s	remaining: 3.46s
# 787:	learn: 4095.5977079	total: 12.8s	remaining: 3.45s
# 788:	learn: 4094.4223598	total: 12.8s	remaining: 3.43s
# 789:	learn: 4091.7615300	total: 12.8s	remaining: 3.41s
# 790:	learn: 4086.7804754	total: 12.9s	remaining: 3.4s
# 791:	learn: 4083.0299966	total: 12.9s	remaining: 3.38s
# 792:	learn: 4082.8243517	total: 12.9s	remaining: 3.36s
# 793:	learn: 4079.7686504	total: 12.9s	remaining: 3.35s
# 794:	learn: 4078.0742650	total: 12.9s	remaining: 3.33s
# 795:	learn: 4074.3442464	total: 12.9s	remaining: 3.31s
# 796:	learn: 4068.2327079	total: 13s	remaining: 3.3s
# 797:	learn: 4067.3820812	total: 13s	remaining: 3.28s
# 798:	learn: 4064.9550450	total: 13s	remaining: 3.27s
# 799:	learn: 4063.4412232	total: 13s	remaining: 3.25s
# 800:	learn: 4060.1859363	total: 13s	remaining: 3.23s
# 801:	learn: 4054.4665665	total: 13s	remaining: 3.22s
# 802:	learn: 4052.8348135	total: 13s	remaining: 3.2s
# 803:	learn: 4051.2788935	total: 13.1s	remaining: 3.18s
# 804:	learn: 4042.5416073	total: 13.1s	remaining: 3.17s
# 805:	learn: 4038.5897261	total: 13.1s	remaining: 3.15s
# 806:	learn: 4037.8511519	total: 13.1s	remaining: 3.13s
# 807:	learn: 4029.4647188	total: 13.1s	remaining: 3.12s
# 808:	learn: 4027.9810986	total: 13.1s	remaining: 3.1s
# 809:	learn: 4025.7024422	total: 13.2s	remaining: 3.08s
# 810:	learn: 4013.5854916	total: 13.2s	remaining: 3.07s
# 811:	learn: 4005.7617408	total: 13.2s	remaining: 3.05s
# 812:	learn: 4001.9918126	total: 13.2s	remaining: 3.04s
# 813:	learn: 4000.9824389	total: 13.2s	remaining: 3.02s
# 814:	learn: 3999.2537977	total: 13.2s	remaining: 3s
# 815:	learn: 3996.6755716	total: 13.2s	remaining: 2.99s
# 816:	learn: 3992.1195229	total: 13.3s	remaining: 2.97s
# 817:	learn: 3991.9346209	total: 13.3s	remaining: 2.95s
# 818:	learn: 3985.9877053	total: 13.3s	remaining: 2.94s
# 819:	learn: 3982.6631709	total: 13.3s	remaining: 2.92s
# 820:	learn: 3981.0108969	total: 13.3s	remaining: 2.9s
# 821:	learn: 3978.1276545	total: 13.3s	remaining: 2.89s
# 822:	learn: 3975.9530522	total: 13.4s	remaining: 2.87s
# 823:	learn: 3962.5064844	total: 13.4s	remaining: 2.86s
# 824:	learn: 3959.3863697	total: 13.4s	remaining: 2.84s
# 825:	learn: 3955.9421427	total: 13.4s	remaining: 2.82s
# 826:	learn: 3927.5477932	total: 13.4s	remaining: 2.81s
# 827:	learn: 3923.7980837	total: 13.4s	remaining: 2.79s
# 828:	learn: 3922.6473317	total: 13.4s	remaining: 2.77s
# 829:	learn: 3919.1845416	total: 13.5s	remaining: 2.76s
# 830:	learn: 3915.8208014	total: 13.5s	remaining: 2.74s
# 831:	learn: 3915.3556176	total: 13.5s	remaining: 2.72s
# 832:	learn: 3915.0472824	total: 13.5s	remaining: 2.71s
# 833:	learn: 3900.8315086	total: 13.5s	remaining: 2.69s
# 834:	learn: 3899.2034812	total: 13.5s	remaining: 2.67s
# 835:	learn: 3896.1573004	total: 13.6s	remaining: 2.66s
# 836:	learn: 3894.3912407	total: 13.6s	remaining: 2.64s
# 837:	learn: 3892.9709030	total: 13.6s	remaining: 2.63s
# 838:	learn: 3891.6870538	total: 13.6s	remaining: 2.61s
# 839:	learn: 3891.6808919	total: 13.6s	remaining: 2.59s
# 840:	learn: 3889.0074711	total: 13.6s	remaining: 2.58s
# 841:	learn: 3886.5496813	total: 13.7s	remaining: 2.56s
# 842:	learn: 3883.4730811	total: 13.7s	remaining: 2.55s
# 843:	learn: 3879.8209587	total: 13.7s	remaining: 2.53s
# 844:	learn: 3877.6625535	total: 13.7s	remaining: 2.51s
# 845:	learn: 3870.9626505	total: 13.7s	remaining: 2.5s
# 846:	learn: 3870.2159366	total: 13.7s	remaining: 2.48s
# 847:	learn: 3870.0943845	total: 13.8s	remaining: 2.46s
# 848:	learn: 3869.3352434	total: 13.8s	remaining: 2.45s
# 849:	learn: 3864.0886323	total: 13.8s	remaining: 2.43s
# 850:	learn: 3863.6856407	total: 13.8s	remaining: 2.42s
# 851:	learn: 3861.5374041	total: 13.8s	remaining: 2.4s
# 852:	learn: 3860.0360215	total: 13.8s	remaining: 2.38s
# 853:	learn: 3859.6668612	total: 13.8s	remaining: 2.37s
# 854:	learn: 3852.2583955	total: 13.9s	remaining: 2.35s
# 855:	learn: 3846.2301690	total: 13.9s	remaining: 2.33s
# 856:	learn: 3842.9420657	total: 13.9s	remaining: 2.32s
# 857:	learn: 3839.4779221	total: 13.9s	remaining: 2.3s
# 858:	learn: 3834.8944373	total: 13.9s	remaining: 2.28s
# 859:	learn: 3830.8628373	total: 13.9s	remaining: 2.27s
# 860:	learn: 3830.6992630	total: 13.9s	remaining: 2.25s
# 861:	learn: 3827.9080841	total: 14s	remaining: 2.23s
# 862:	learn: 3827.0742161	total: 14s	remaining: 2.22s
# 863:	learn: 3821.4513086	total: 14s	remaining: 2.2s
# 864:	learn: 3819.2085384	total: 14s	remaining: 2.19s
# 865:	learn: 3816.3858134	total: 14s	remaining: 2.17s
# 866:	learn: 3816.2292722	total: 14s	remaining: 2.15s
# 867:	learn: 3813.8609797	total: 14.1s	remaining: 2.14s
# 868:	learn: 3813.7297142	total: 14.1s	remaining: 2.12s
# 869:	learn: 3804.2812725	total: 14.1s	remaining: 2.1s
# 870:	learn: 3804.2790044	total: 14.1s	remaining: 2.09s
# 871:	learn: 3802.9415420	total: 14.1s	remaining: 2.07s
# 872:	learn: 3802.2070761	total: 14.1s	remaining: 2.06s
# 873:	learn: 3793.9581319	total: 14.1s	remaining: 2.04s
# 874:	learn: 3793.2264161	total: 14.2s	remaining: 2.02s
# ...
# 715:	learn: 46727.8751652	total: 1.33s	remaining: 526ms
# 716:	learn: 46721.8750835	total: 1.33s	remaining: 524ms
# 717:	learn: 46700.2174666	total: 1.33s	remaining: 523ms
# 718:	learn: 46684.7658004	total: 1.33s	remaining: 521ms
# 719:	learn: 46674.2886600	total: 1.33s	remaining: 519ms
# 720:	learn: 46660.0336890	total: 1.34s	remaining: 517ms
# 721:	learn: 46647.6947905	total: 1.34s	remaining: 515ms
# 722:	learn: 46638.7807306	total: 1.34s	remaining: 513ms
# 723:	learn: 46627.8996977	total: 1.34s	remaining: 512ms
# 724:	learn: 46620.8181889	total: 1.34s	remaining: 510ms
# 725:	learn: 46606.5916261	total: 1.34s	remaining: 508ms
# 726:	learn: 46598.7254124	total: 1.35s	remaining: 506ms
# 727:	learn: 46591.0034514	total: 1.35s	remaining: 504ms
# 728:	learn: 46579.6471397	total: 1.35s	remaining: 502ms
# 729:	learn: 46566.2835279	total: 1.35s	remaining: 500ms
# 730:	learn: 46562.5687340	total: 1.35s	remaining: 499ms
# 731:	learn: 46560.0180508	total: 1.36s	remaining: 497ms
# 732:	learn: 46559.5126534	total: 1.36s	remaining: 495ms
# 733:	learn: 46549.1838405	total: 1.36s	remaining: 493ms
# 734:	learn: 46542.0543829	total: 1.36s	remaining: 491ms
# 735:	learn: 46523.7603814	total: 1.36s	remaining: 489ms
# 736:	learn: 46513.0710752	total: 1.36s	remaining: 487ms
# 737:	learn: 46499.0383435	total: 1.37s	remaining: 486ms
# 738:	learn: 46486.7003742	total: 1.37s	remaining: 484ms
# 739:	learn: 46486.2509492	total: 1.37s	remaining: 482ms
# 740:	learn: 46481.1176975	total: 1.37s	remaining: 480ms
# 741:	learn: 46468.7794726	total: 1.38s	remaining: 478ms
# 742:	learn: 46465.8940355	total: 1.38s	remaining: 476ms
# 743:	learn: 46459.5720642	total: 1.38s	remaining: 474ms
# 744:	learn: 46452.5250607	total: 1.38s	remaining: 473ms
# 745:	learn: 46434.5965555	total: 1.38s	remaining: 471ms
# 746:	learn: 46416.4155561	total: 1.38s	remaining: 469ms
# 747:	learn: 46407.1961428	total: 1.39s	remaining: 467ms
# 748:	learn: 46387.3889857	total: 1.39s	remaining: 465ms
# 749:	learn: 46378.3365806	total: 1.39s	remaining: 463ms
# 750:	learn: 46369.2256016	total: 1.39s	remaining: 461ms
# 751:	learn: 46357.6585176	total: 1.39s	remaining: 459ms
# 752:	learn: 46345.3772159	total: 1.4s	remaining: 458ms
# 753:	learn: 46342.5329477	total: 1.4s	remaining: 456ms
# 754:	learn: 46331.4940945	total: 1.4s	remaining: 454ms
# 755:	learn: 46324.8687689	total: 1.4s	remaining: 452ms
# 756:	learn: 46308.3491522	total: 1.4s	remaining: 450ms
# 757:	learn: 46305.0217899	total: 1.4s	remaining: 448ms
# 758:	learn: 46296.1356388	total: 1.41s	remaining: 447ms
# 759:	learn: 46282.1747492	total: 1.41s	remaining: 445ms
# 760:	learn: 46270.5603216	total: 1.41s	remaining: 443ms
# 761:	learn: 46259.3648750	total: 1.41s	remaining: 442ms
# 762:	learn: 46255.9173879	total: 1.42s	remaining: 440ms
# 763:	learn: 46249.1815811	total: 1.42s	remaining: 439ms
# 764:	learn: 46233.9038927	total: 1.42s	remaining: 437ms
# 765:	learn: 46230.4084412	total: 1.42s	remaining: 435ms
# 766:	learn: 46220.5969705	total: 1.43s	remaining: 433ms
# 767:	learn: 46207.6935397	total: 1.43s	remaining: 431ms
# 768:	learn: 46204.5607162	total: 1.43s	remaining: 429ms
# 769:	learn: 46191.8376607	total: 1.43s	remaining: 428ms
# 770:	learn: 46186.9260567	total: 1.43s	remaining: 426ms
# 771:	learn: 46176.9995194	total: 1.44s	remaining: 424ms
# 772:	learn: 46169.2589542	total: 1.46s	remaining: 428ms
# 773:	learn: 46155.9182412	total: 1.46s	remaining: 426ms
# 774:	learn: 46152.1849107	total: 1.46s	remaining: 425ms
# 775:	learn: 46117.7240813	total: 1.46s	remaining: 423ms
# 776:	learn: 46102.1567130	total: 1.47s	remaining: 421ms
# 777:	learn: 46099.2006855	total: 1.47s	remaining: 419ms
# 778:	learn: 46096.8971228	total: 1.47s	remaining: 417ms
# 779:	learn: 46085.2278993	total: 1.47s	remaining: 415ms
# 780:	learn: 46078.3751236	total: 1.47s	remaining: 413ms
# 781:	learn: 46075.3038915	total: 1.48s	remaining: 411ms
# 782:	learn: 46063.0614290	total: 1.48s	remaining: 409ms
# 783:	learn: 46039.5913988	total: 1.48s	remaining: 408ms
# 784:	learn: 46036.9047405	total: 1.48s	remaining: 406ms
# 785:	learn: 46017.1978387	total: 1.48s	remaining: 404ms
# 786:	learn: 45996.8176874	total: 1.48s	remaining: 402ms
# 787:	learn: 45996.3441993	total: 1.49s	remaining: 400ms
# 788:	learn: 45975.5299374	total: 1.49s	remaining: 398ms
# 789:	learn: 45969.8989627	total: 1.49s	remaining: 396ms
# 790:	learn: 45963.2046822	total: 1.49s	remaining: 394ms
# 791:	learn: 45960.1418552	total: 1.49s	remaining: 392ms
# 792:	learn: 45956.3504697	total: 1.5s	remaining: 390ms
# 793:	learn: 45946.0637551	total: 1.5s	remaining: 388ms
# 794:	learn: 45935.2469071	total: 1.5s	remaining: 387ms
# 795:	learn: 45932.1477096	total: 1.5s	remaining: 385ms
# 796:	learn: 45919.8151446	total: 1.5s	remaining: 383ms
# 797:	learn: 45912.3383708	total: 1.5s	remaining: 381ms
# 798:	learn: 45911.9022996	total: 1.51s	remaining: 379ms
# 799:	learn: 45899.9905572	total: 1.51s	remaining: 377ms
# 800:	learn: 45892.2497414	total: 1.51s	remaining: 375ms
# 801:	learn: 45868.8786383	total: 1.51s	remaining: 373ms
# 802:	learn: 45864.5145243	total: 1.51s	remaining: 371ms
# 803:	learn: 45861.5310345	total: 1.51s	remaining: 369ms
# 804:	learn: 45854.7508350	total: 1.52s	remaining: 368ms
# 805:	learn: 45845.7062894	total: 1.52s	remaining: 366ms
# 806:	learn: 45834.3980204	total: 1.52s	remaining: 364ms
# 807:	learn: 45831.5357410	total: 1.52s	remaining: 362ms
# 808:	learn: 45814.7224921	total: 1.52s	remaining: 360ms
# 809:	learn: 45801.8019111	total: 1.53s	remaining: 358ms
# 810:	learn: 45789.9549242	total: 1.53s	remaining: 356ms
# 811:	learn: 45783.6644836	total: 1.53s	remaining: 354ms
# 812:	learn: 45777.7663692	total: 1.53s	remaining: 352ms
# 813:	learn: 45765.6887469	total: 1.53s	remaining: 351ms
# 814:	learn: 45753.9243700	total: 1.54s	remaining: 349ms
# 815:	learn: 45742.3971718	total: 1.54s	remaining: 347ms
# 816:	learn: 45740.2649156	total: 1.54s	remaining: 345ms
# 817:	learn: 45737.9460550	total: 1.54s	remaining: 343ms
# 818:	learn: 45733.1098977	total: 1.54s	remaining: 341ms
# 819:	learn: 45729.1004801	total: 1.54s	remaining: 339ms
# 820:	learn: 45728.5039976	total: 1.55s	remaining: 337ms
# 821:	learn: 45709.9360391	total: 1.55s	remaining: 335ms
# 822:	learn: 45689.2540345	total: 1.55s	remaining: 333ms
# 823:	learn: 45686.6897536	total: 1.55s	remaining: 332ms
# 824:	learn: 45677.3694814	total: 1.55s	remaining: 330ms
# 825:	learn: 45675.1236201	total: 1.56s	remaining: 328ms
# 826:	learn: 45661.5227256	total: 1.56s	remaining: 326ms
# 827:	learn: 45657.5141645	total: 1.56s	remaining: 324ms
# 828:	learn: 45655.1629054	total: 1.56s	remaining: 322ms
# 829:	learn: 45640.6171560	total: 1.56s	remaining: 320ms
# 830:	learn: 45639.8749532	total: 1.57s	remaining: 319ms
# 831:	learn: 45632.4625115	total: 1.57s	remaining: 317ms
# 832:	learn: 45623.0999991	total: 1.57s	remaining: 315ms
# 833:	learn: 45622.6629729	total: 1.57s	remaining: 313ms
# 834:	learn: 45614.9255832	total: 1.57s	remaining: 311ms
# 835:	learn: 45612.3099104	total: 1.57s	remaining: 309ms
# 836:	learn: 45600.1671429	total: 1.58s	remaining: 307ms
# 837:	learn: 45593.5788733	total: 1.58s	remaining: 305ms
# 838:	learn: 45590.8928433	total: 1.58s	remaining: 303ms
# 839:	learn: 45587.6238854	total: 1.58s	remaining: 301ms
# 840:	learn: 45584.7999459	total: 1.58s	remaining: 300ms
# 841:	learn: 45578.4452982	total: 1.59s	remaining: 298ms
# 842:	learn: 45571.8925683	total: 1.59s	remaining: 296ms
# 843:	learn: 45551.8005993	total: 1.59s	remaining: 294ms
# 844:	learn: 45543.4494894	total: 1.59s	remaining: 292ms
# 845:	learn: 45527.2434483	total: 1.59s	remaining: 290ms
# 846:	learn: 45522.3356765	total: 1.59s	remaining: 288ms
# 847:	learn: 45519.6875356	total: 1.6s	remaining: 286ms
# 848:	learn: 45511.4247158	total: 1.6s	remaining: 285ms
# 849:	learn: 45502.2212353	total: 1.6s	remaining: 283ms
# 850:	learn: 45499.3345692	total: 1.6s	remaining: 281ms
# 851:	learn: 45486.4416077	total: 1.61s	remaining: 279ms
# 852:	learn: 45475.1409693	total: 1.61s	remaining: 277ms
# 853:	learn: 45461.8818320	total: 1.61s	remaining: 275ms
# 854:	learn: 45461.2088671	total: 1.61s	remaining: 273ms
# 855:	learn: 45457.3992701	total: 1.61s	remaining: 272ms
# 856:	learn: 45454.8635608	total: 1.62s	remaining: 270ms
# 857:	learn: 45447.1016373	total: 1.62s	remaining: 268ms
# 858:	learn: 45441.7436936	total: 1.62s	remaining: 266ms
# 859:	learn: 45416.6864479	total: 1.62s	remaining: 264ms
# 860:	learn: 45408.4123857	total: 1.63s	remaining: 262ms
# 861:	learn: 45395.1957648	total: 1.63s	remaining: 260ms
# 862:	learn: 45387.0174980	total: 1.63s	remaining: 259ms
# 863:	learn: 45376.8231764	total: 1.63s	remaining: 257ms
# 864:	learn: 45366.0852129	total: 1.63s	remaining: 255ms
# 865:	learn: 45358.1651744	total: 1.63s	remaining: 253ms
# 866:	learn: 45356.6038458	total: 1.64s	remaining: 251ms
# 867:	learn: 45354.6427634	total: 1.64s	remaining: 249ms
# 868:	learn: 45347.9592381	total: 1.64s	remaining: 247ms
# 869:	learn: 45342.6343797	total: 1.64s	remaining: 245ms
# 870:	learn: 45335.1044973	total: 1.64s	remaining: 243ms
# 871:	learn: 45330.2755114	total: 1.65s	remaining: 242ms
# 872:	learn: 45326.2484327	total: 1.65s	remaining: 240ms
# 873:	learn: 45318.4011785	total: 1.65s	remaining: 238ms
# 874:	learn: 45315.9841391	total: 1.65s	remaining: 236ms
# 875:	learn: 45306.5063384	total: 1.65s	remaining: 234ms
# 876:	learn: 45298.8917680	total: 1.66s	remaining: 232ms
# 877:	learn: 45290.2773380	total: 1.66s	remaining: 230ms
# 878:	learn: 45277.6139301	total: 1.66s	remaining: 228ms
# 879:	learn: 45274.7514020	total: 1.66s	remaining: 227ms
# 880:	learn: 45273.5006960	total: 1.66s	remaining: 225ms
# 881:	learn: 45253.2748490	total: 1.66s	remaining: 223ms
# 882:	learn: 45252.2191253	total: 1.67s	remaining: 221ms
# 883:	learn: 45247.5869050	total: 1.67s	remaining: 219ms
# 884:	learn: 45241.4437432	total: 1.67s	remaining: 217ms
# 885:	learn: 45239.9264148	total: 1.67s	remaining: 215ms
# 886:	learn: 45230.0266694	total: 1.67s	remaining: 213ms
# 887:	learn: 45220.6269493	total: 1.68s	remaining: 211ms
# 888:	learn: 45214.2219142	total: 1.68s	remaining: 209ms
# 889:	learn: 45207.1166188	total: 1.68s	remaining: 207ms
# 890:	learn: 45195.3175792	total: 1.68s	remaining: 206ms
# 891:	learn: 45188.5824875	total: 1.68s	remaining: 204ms
# 892:	learn: 45182.2000418	total: 1.68s	remaining: 202ms
# 893:	learn: 45176.1499866	total: 1.69s	remaining: 200ms
# 894:	learn: 45159.1969764	total: 1.69s	remaining: 198ms
# 895:	learn: 45157.7815542	total: 1.69s	remaining: 196ms
# 896:	learn: 45147.6670966	total: 1.69s	remaining: 194ms
# 897:	learn: 45141.9329638	total: 1.69s	remaining: 192ms
# 898:	learn: 45135.3452843	total: 1.7s	remaining: 191ms
# 899:	learn: 45132.5672801	total: 1.7s	remaining: 189ms
# 900:	learn: 45131.5568598	total: 1.7s	remaining: 187ms
# 901:	learn: 45120.0518978	total: 1.7s	remaining: 185ms
# 902:	learn: 45114.0710007	total: 1.7s	remaining: 183ms
# 903:	learn: 45100.5670748	total: 1.71s	remaining: 181ms
# 904:	learn: 45083.2314558	total: 1.71s	remaining: 179ms
# 905:	learn: 45082.6536414	total: 1.71s	remaining: 177ms
# 906:	learn: 45077.3251635	total: 1.71s	remaining: 175ms
# 907:	learn: 45072.2721421	total: 1.71s	remaining: 174ms
# 908:	learn: 45064.1732637	total: 1.71s	remaining: 172ms
# 909:	learn: 45051.1479382	total: 1.72s	remaining: 170ms
# 910:	learn: 45046.9814523	total: 1.72s	remaining: 168ms
# 911:	learn: 45036.3671988	total: 1.72s	remaining: 166ms
# 912:	learn: 45028.2519006	total: 1.72s	remaining: 164ms
# 913:	learn: 45026.0138988	total: 1.72s	remaining: 162ms
# 914:	learn: 45022.4907707	total: 1.73s	remaining: 160ms
# 915:	learn: 45017.6878306	total: 1.73s	remaining: 158ms
# 916:	learn: 44995.0164831	total: 1.73s	remaining: 157ms
# 917:	learn: 44991.3923590	total: 1.73s	remaining: 155ms
# 918:	learn: 44981.9399704	total: 1.73s	remaining: 153ms
# 919:	learn: 44978.6670921	total: 1.74s	remaining: 151ms
# 920:	learn: 44974.0167583	total: 1.74s	remaining: 149ms
# 921:	learn: 44968.3145742	total: 1.74s	remaining: 147ms
# 922:	learn: 44967.7672171	total: 1.74s	remaining: 145ms
# 923:	learn: 44966.3427019	total: 1.74s	remaining: 143ms
# 924:	learn: 44959.4213916	total: 1.74s	remaining: 141ms
# 925:	learn: 44939.7317474	total: 1.75s	remaining: 140ms
# 926:	learn: 44928.2733764	total: 1.75s	remaining: 138ms
# 927:	learn: 44925.8530480	total: 1.75s	remaining: 136ms
# 928:	learn: 44919.5970808	total: 1.75s	remaining: 134ms
# 929:	learn: 44910.4554868	total: 1.75s	remaining: 132ms
# 930:	learn: 44908.4991972	total: 1.75s	remaining: 130ms
# 931:	learn: 44900.0323069	total: 1.76s	remaining: 128ms
# 932:	learn: 44897.1132385	total: 1.76s	remaining: 126ms
# 933:	learn: 44893.1401608	total: 1.76s	remaining: 124ms
# 934:	learn: 44884.7636602	total: 1.76s	remaining: 123ms
# 935:	learn: 44875.1320613	total: 1.76s	remaining: 121ms
# 936:	learn: 44872.1395414	total: 1.77s	remaining: 119ms
# 937:	learn: 44870.9583465	total: 1.77s	remaining: 117ms
# 938:	learn: 44864.1453235	total: 1.77s	remaining: 115ms
# 939:	learn: 44862.1694232	total: 1.77s	remaining: 113ms
# 940:	learn: 44853.9678478	total: 1.77s	remaining: 111ms
# 941:	learn: 44852.2375568	total: 1.77s	remaining: 109ms
# 942:	learn: 44851.3048772	total: 1.78s	remaining: 107ms
# 943:	learn: 44846.5816875	total: 1.78s	remaining: 106ms
# 944:	learn: 44831.8254356	total: 1.78s	remaining: 104ms
# 945:	learn: 44830.6525319	total: 1.78s	remaining: 102ms
# 946:	learn: 44826.0911851	total: 1.78s	remaining: 99.9ms
# 947:	learn: 44821.0866577	total: 1.79s	remaining: 98ms
# 948:	learn: 44816.9651799	total: 1.79s	remaining: 96.1ms
# 949:	learn: 44815.3363459	total: 1.79s	remaining: 94.3ms
# 950:	learn: 44807.5188886	total: 1.79s	remaining: 92.5ms
# 951:	learn: 44802.5220658	total: 1.8s	remaining: 90.6ms
# 952:	learn: 44793.4568496	total: 1.8s	remaining: 88.8ms
# 953:	learn: 44784.2529519	total: 1.8s	remaining: 86.9ms
# 954:	learn: 44771.9087500	total: 1.8s	remaining: 85ms
# 955:	learn: 44765.3933468	total: 1.8s	remaining: 83.1ms
# 956:	learn: 44761.6177286	total: 1.81s	remaining: 81.2ms
# 957:	learn: 44747.1474890	total: 1.81s	remaining: 79.3ms
# 958:	learn: 44746.2467571	total: 1.81s	remaining: 77.4ms
# 959:	learn: 44738.1992581	total: 1.81s	remaining: 75.5ms
# 960:	learn: 44734.6725087	total: 1.81s	remaining: 73.7ms
# 961:	learn: 44718.1502845	total: 1.82s	remaining: 71.8ms
# 962:	learn: 44712.8220011	total: 1.82s	remaining: 69.9ms
# 963:	learn: 44706.4705399	total: 1.82s	remaining: 68ms
# 964:	learn: 44699.0652766	total: 1.82s	remaining: 66.1ms
# 965:	learn: 44686.6604196	total: 1.82s	remaining: 64.2ms
# 966:	learn: 44681.2776439	total: 1.83s	remaining: 62.3ms
# 967:	learn: 44668.6832318	total: 1.83s	remaining: 60.5ms
# 968:	learn: 44665.4907092	total: 1.83s	remaining: 58.6ms
# 969:	learn: 44661.2293073	total: 1.83s	remaining: 56.7ms
# 970:	learn: 44650.8150504	total: 1.83s	remaining: 54.8ms
# 971:	learn: 44646.7646050	total: 1.84s	remaining: 52.9ms
# 972:	learn: 44646.3945192	total: 1.84s	remaining: 51ms
# 973:	learn: 44638.6723443	total: 1.84s	remaining: 49.1ms
# 974:	learn: 44638.3312370	total: 1.84s	remaining: 47.2ms
# 975:	learn: 44627.8494903	total: 1.84s	remaining: 45.3ms
# 976:	learn: 44626.2351615	total: 1.84s	remaining: 43.4ms
# 977:	learn: 44619.1375672	total: 1.85s	remaining: 41.6ms
# 978:	learn: 44617.6543086	total: 1.85s	remaining: 39.7ms
# 979:	learn: 44609.8746767	total: 1.85s	remaining: 37.8ms
# 980:	learn: 44604.3003741	total: 1.85s	remaining: 35.9ms
# 981:	learn: 44601.6315187	total: 1.85s	remaining: 34ms
# 982:	learn: 44596.1644795	total: 1.86s	remaining: 32.1ms
# 983:	learn: 44588.6152311	total: 1.86s	remaining: 30.2ms
# 984:	learn: 44586.9410376	total: 1.86s	remaining: 28.4ms
# 985:	learn: 44580.6671013	total: 1.86s	remaining: 26.5ms
# 986:	learn: 44580.4051942	total: 1.86s	remaining: 24.6ms
# 987:	learn: 44570.7175686	total: 1.87s	remaining: 22.7ms
# 988:	learn: 44559.1534810	total: 1.87s	remaining: 20.8ms
# 989:	learn: 44547.2820793	total: 1.87s	remaining: 18.9ms
# 990:	learn: 44543.8568203	total: 1.87s	remaining: 17ms
# 991:	learn: 44539.0968292	total: 1.87s	remaining: 15.1ms
# 992:	learn: 44529.9360561	total: 1.88s	remaining: 13.2ms
# 993:	learn: 44519.7036424	total: 1.88s	remaining: 11.3ms
# 994:	learn: 44509.4690706	total: 1.88s	remaining: 9.45ms
# 995:	learn: 44500.3922262	total: 1.88s	remaining: 7.56ms
# 996:	learn: 44495.0521420	total: 1.88s	remaining: 5.67ms
# 997:	learn: 44488.0704570	total: 1.89s	remaining: 3.78ms
# 998:	learn: 44483.7231053	total: 1.89s	remaining: 1.89ms
# 999:	learn: 44477.7299855	total: 1.89s	remaining: 0us

# %%
#2, 3
param_grid = {
        "n_estimators": [100, 1000, 2000], 
        "max_depth"   : [5, 6, 7],
        "learning_rate": [1e-2, 1e-1, 1]
}
for i in ['A', 'B', 'C']:
    if i == 'A':
        model = CatBoostRegressor(logging_level = 'Silent', cat_features = cols_to_exclude)
    else:
        model = CatBoostRegressor(logging_level = 'Silent')
    # Perform grid search, fit it, and print score
    t = time.time()
    regressor = GridSearchCV(estimator = model, param_grid = param_grid, cv = 2)
    regressor.fit(X_train[i], y_train[i])
    res_t = time.time() - t
    predictions_test = regressor.predict(X_test[i])
    predictions_train = regressor.predict(X_train[i])
    mae_train = mean_absolute_error(predictions_train, y_train[i])
    mae_test  = mean_absolute_error(predictions_test, y_test[i])
    insert(df_catboost, [i + '_train', regressor.best_params_, res_t, mae_train])
    insert(df_catboost, [i + '_test', regressor.best_params_, res_t, mae_test])

# %%
df_catboost
# Out:
#    Dataset                                         Parameters        Time  \
# 0   A_test  {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...   16.493989
# 1   B_test  {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...    1.938971
# 2   C_test  {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...    2.067674
# 3  A_train  {'learning_rate': 1, 'max_depth': 6, 'n_estima...  964.107443
# 4   A_test  {'learning_rate': 1, 'max_depth': 6, 'n_estima...  964.107443
# 5  B_train  {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...  129.048228
# 6   B_test  {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...  129.048228
# 7  C_train  {'learning_rate': 1, 'max_depth': 5, 'n_estima...  108.950871
# 8   C_test  {'learning_rate': 1, 'max_depth': 5, 'n_estima...  108.950871
#
#             MAE
# 0   3864.126152
# 1  15807.439220
# 2  28077.250806
# 3   4188.761724
# 4   8436.718119
# 5   5805.033817
# 6  15329.698347
# 7  23272.907604
# 8  28931.743101

# %% [markdown]
# **Ваши выводы:** Категориальные признаки и подбор параметров полезны. Время на выполнение в этот раз ниже.

# %% [markdown]
# И так, мы наконец познакомились со всеми библиотеками градиентного бустинга.
#
# ## Обобщение результатов
#
# На текущем этапе у вас должно быть несколько датафреймов результатами по каждой библиотеке. Мы, конечно, сделали некоторые выводы, но пришло время собрать это в красивый отчет.
#
# ### Задание 6 (кросс-проверка, 3 балла):
# **Данные**: датасет с ценами поддержанных автомобилей
# **Цели**: В данном задании следует выполнить следующие пункты:
# 1. При помощи одного или нескольких графиков показать результаты различных библиотек: времени работы и качество результатов. Можете воспользоваться любым типом графиков: гистограммы, scatter и т.д. По этим графикам должно быть понятно какая библиотека и насколько быстрее, насколько различается их качество, сравнение оптимизированных и неоптимизированных параметров.
# 2. По графикам сравните библиотеки, производительность и качество работы. Опишите ваши выводы ниже.

# %%
# Your great pictures and conclusions below!
ds = [df_skl, df_lightgbm, df_xgbr, df_catboost]
times = [x["Time"].mean() for x in ds]
maes = [x["MAE"].mean() for x in ds]
plt.figure(figsize=(12, 8))
plt.scatter(times[0], maes[0])
plt.scatter(times[1], maes[1])
plt.scatter(times[2], maes[2])
plt.scatter(times[3], maes[3])
plt.legend(["Sklearn", "Lightgbm", "Xgb", "Catboost"])
plt.xlabel("Время обучения, с")
plt.ylabel("MAE")
plt.title("Зависимость консолидированного времени обучения от консолидированной ошибки")
plt.show()

# %% [markdown]
# **Ваши выводы:** Catboost оказалось довольно долгой в реализации. Lightgbm дало наибольшую ошибку. Xgb и Sklearn дали самые быстрые и точные результаты.

# %% [markdown]
# ## Оптимизация параметров с hyperopt
#
# И так, мы с вами научились пользоваться библиотеками для градиентного бустинга. И я почти уверен, что знаю вашу самую "любимую" часть всех этих заданий: оптимизация параметров. Она достаточно долгая, нудная, да еще и над сетками перебора нужно думать. Значит сейчас, когда вы поняли всю тяжесть этого процесса, мы можем узнать как относительно быстро и безболезненно нащупать оптимальные параметры!

# %% [markdown]
# [Эмоции выполняющего в этот момент.](https://disk.yandex.ru/i/qwkvBEFrWYoV9A)

# %% [markdown]
# Нашего спасителя зовут HyperOpt. На первый взгляд hyperopt делает всё то же самое, что и grid search, а именно перебирает параметры. По факту же hyperopt превращает это в задачу оптимизации, используя некоторые эвристики для ускорения сходимости процесса. К тому же, он требует лишь информацию о границе интарвалов, а не сами сетки. В теории это должно помочь нам добиться лучших результатов за более короткое время. Давайте попробуем это сделать.
#
# Для данного эксперимента я рекомендую использовать lightgbm, поскольку она быстрее и с ней удобнее играться, но Вы можете воспользоваться любой библиотекой из представленных выше.
#
# ### Задание 7 (кросс-проверка, 4 балла):
# **Данные**: датасет со стоимостью поддержанных автомобилей
# **Метрика**: MAE
# **Цели**: В данном задании следует выполнить следующие пункты:
# 1. Взять любую библиотеку градиентного бустинга (можете взять самую быструю)
# 2. Составить сетку перебора в hyperopt, включающую параметры n_estimators, max_depth и learning_rate в hyperopt. Вам могут понадобиться такие типы данных, как hp.choise, hp.qloguniform, hp.uniform и hp.quniform (можно также пользоваться np.arange). Также для округления значения типа float до целых чисел (4.0 -> 4) используйте `scope.int`.
# 3. Реализуйте функцию, которая принимает на вход словарь параметров для регрессора, и при помощи cv оценивает его качество на датасете A (можно воспользоваться cross_val_score, а для ускорения поставить cv=3). Не забудьте о том, в каком виде lightgbm принимает категориальные признаки в numpy и что также надо передавать индексы категориальных признаков.
# 4. Создайте объект trials=Trials(), который будет хранить информацию о процессе оптимизации.
# 5. Используя функцию fmin, оптимизируйте Вашу функцию. Установите algo=tpe.suggest, trials=trials и max_evals, по крайней мере, 50. verbose=1 позволит видеть прогресс-бар по типу tqdm.
# 6. Выведите получившиеся параметры. Нарисуйте график, показывающий значение loss в ходе оптимизации. Посчитайте качество на тесте при использовании лучших параметров (возвращаются после использования fmin). Сделайте выводы по результату.

# %%
import warnings
warnings.filterwarnings("ignore")

trials = Trials()

def quality(params):
    # your cool function here
    return # something

grid = {
    # your clever grid here
}

best = fmin(fn=quality,
                space = grid,
                algo = tpe.suggest,
                max_evals = 50,
                trials = trials,
               verbose = 1)


# your super code for super graph
plt.figure(figsize = (15, 15))
plt.xlabel("Попытки")
plt.ylabel("loss")
plt.title("значение loss в ходе оптимизации")
plt.plot(trials.losses())
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4520/2192924254.py in <module>
#      12 }
#      13
# ---> 14 best = fmin(fn=quality,
#      15                 space = grid,
#      16                 algo = tpe.suggest,
#
# ~\miniconda3\envs\prak\lib\site-packages\hyperopt\fmin.py in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     505
#     506     if allow_trials_fmin and hasattr(trials, "fmin"):
# --> 507         return trials.fmin(
#     508             fn,
#     509             space,
#
# ~\miniconda3\envs\prak\lib\site-packages\hyperopt\base.py in fmin(self, fn, space, algo, max_evals, timeout, loss_threshold, max_queue_len, rstate, verbose, pass_expr_memo_ctrl, catch_eval_exceptions, return_argmin, show_progressbar, early_stop_fn, trials_save_file)
#     680         from .fmin import fmin
#     681
# --> 682         return fmin(
#     683             fn,
#     684             space,
#
# ~\miniconda3\envs\prak\lib\site-packages\hyperopt\fmin.py in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     532             trials = generate_trials_to_calculate(points_to_evaluate)
#     533
# --> 534     domain = base.Domain(fn, space, pass_expr_memo_ctrl=pass_expr_memo_ctrl)
#     535
#     536     rval = FMinIter(
#
# ~\miniconda3\envs\prak\lib\site-packages\hyperopt\base.py in __init__(self, fn, expr, workdir, pass_expr_memo_ctrl, name, loss_target)
#     850         before = pyll.dfs(self.expr)
#     851         # -- raises exception if expr contains cycles
# --> 852         pyll.toposort(self.expr)
#     853         vh = self.vh = VectorizeHelper(self.expr, self.s_new_ids)
#     854         # -- raises exception if v_expr contains cycles
#
# ~\miniconda3\envs\prak\lib\site-packages\hyperopt\pyll\base.py in toposort(expr)
#     710         G.add_edges_from([(n_in, node) for n_in in node.inputs()])
#     711     order = list(nx.topological_sort(G))
# --> 712     assert order[-1] == expr
#     713     return order
#     714
#
# IndexError: list index out of range

# %%
best

# %%
model = LGBMRegressor(n_estimators = 597, max_depth = 6, learning_rate = 0.3568230897704992)
model.fit(X_train['A'], y_train['A'])
prediction = model.predict(X_test["A"])
mean_absolute_error(prediction, y_test["A"])

# %% [markdown]
# **Ваши выводы:**

# %% [markdown]
# ## Предсказание зрительских симпатий
#
# Ну что, детишки, а теперь перейдём к действительно важным вопросам.
#
# **Внимание!** Следующее задание сдается в системе cv-gml.ru, задание `Град. бустинг (ML)` Для выполнения этого задания необходимо скачать датасет из задания. Здесь вы можете немного почитать про датасет и, при желании, поэкспериментировать. На cv-gml.ru загружайте уже готовый скрипт с подобранными параметрами для обучаемого регрессора. Релизовать код необходимо в шаблонном файле awards_prediction.py, который вы можете найти в проверяющей системе.
#
# В некотором царстве, некотором государстве была развита кинопромышленность. Новые фильмы в этом государстве показывают по интернету, а пользователи после просмотра могут дать фильму некоторую "награду". Наша цель - предсказать число наград для фильма.
#
# В нашем распоряжении имеются следующие данные:
#
# **awards** - количество наград, полученных фильмом от пользователей (целевое значение)
# **potions** - количество магических зелий, потраченных на создание спец-эффектов
# **genres** - жанры созданного фильма
# **questions** - количество вопросов, заданных пользователями на соответствующих форумах об этом фильме до премьеры
# **directors** - режиссеры фильма (если неизвестны, то unknown)
# **filming_locations** - области, в которых снимался фильм
# **runtime** - продолжительность фильма в некоторых единицах, принятых в этом государстве
# **critics_liked** - количество критиков из 100, присудивших награды фильму на предварительных закрытых показах
# **pre-orders** - количество зрителей, заранее купивших билеты на первый показ
# **keywords** - ключевые слова, описывающие содержание фильма
# **release_year** - год, во котором фильм был показан (конечно, в летоисчислении этого государства)
#
# Следующие поля появляются несколько раз с разными значениями i:
#
# **actor_i_known_movies** - количество известных фильмов актера i (i от 1 до 3)
#
# **actor_i_postogramm** - количество подписчиков в социальной сети "по сто грамм" актера i (i от 1 до 3)
#
# **actor_i_gender** - пол актера i (i от 1 до 3)
#
# **actor_i_age** - возраст актера i (i от 1 до 3)
#
# -----
# **Внимание!** Учтите, что при OHE кодировании признаки на обучении и тестировании должны совпадать! Если вы примените простое .get_dummies() или что-то подобное, то признаки на трейне и тесте получатся разные! Так что вам, вероятно, придётся придумать способ для того, чтобы сохранить их :)
#
# ### Задание 8 (ML задание, 20 баллов):
# **Данные**: датасет с ценами поддержанных автомобилей
# **Метрика**: MAE
# **Цели**: В данном задании следует выполнить следующие пункты:
# 1. Взять любую библиотеку градиентного бустинга
# 2. Используя предложенный датасет, обучить регрессор для предсказания awards (предоставляем полную свободу в настройках и выборе методов)
# 3. Загрузить решение и получить качество на закрытой выборке больше порогового значения

# %%
## your efficient code here

# %% [markdown]
# ## Конец
#
# Ну что детишки... Можете добавлять еще 4 библиотеки в своё резюме датасаентиста!
